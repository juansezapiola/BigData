# %%
#------------------Parte A-------------------#

# %%
#Ejercicio 1
     
import requests

#busamos algun ítem de interés: Iphone 14 pro max 
buscar = "iphone 14 pro max"
url = "https://api.mercadolibre.com/sites/{}/search?q={}".format("MLA", buscar.replace(" ", "%20"))
response = requests.request("GET", url)
print(response) #Correcto 

#Chequeamos que el url sea el correcto
url

#Guardamos el resultado en un diccionario (json)
data = response.json()
#data                           #para ver su contenido
# Out:
# <Response [200]>
# {'site_id': 'MLA',
#  'country_default_time_zone': 'GMT-03:00',
#  'query': 'iphone 14 pro max',
#  'paging': {'total': 199, 'primary_results': 14, 'offset': 0, 'limit': 50},
#  'results': [{'id': 'MLA1890488344',
#    'title': 'Apple iPhone 14 Pro Max (128 Gb) - Negro + 85% Bateria',
#    'condition': 'new',
#    'thumbnail_id': '720140-MLA78622426123_082024',
#    'catalog_product_id': 'MLA19615313',
#    'listing_type_id': 'gold_special',
#    'sanitized_title': 'apple-iphone-14-pro-max-128-gb-negro-85-bateria',
#    'permalink': 'https://articulo.mercadolibre.com.ar/MLA-1890488344-apple-iphone-14-pro-max-128-gb-negro-85-bateria-_JM',
#    'buying_mode': 'buy_it_now',
#    'site_id': 'MLA',
#    'category_id': 'MLA1055',
#    'domain_id': 'MLA-CELLPHONES',
#    'variation_id': '184445855981',
#    'thumbnail': 'http://http2.mlstatic.com/D_720140-MLA78622426123_082024-O.jpg',
#    'currency_id': 'ARS',
#    'order_backend': 1,
#    'price': 1720000,
#    'original_price': None,
#    'sale_price': {'price_id': '',
#     'amount': 1720000,
#     'conditions': {'eligible': True,
#      'context_restrictions': ['channel_marketplace'],
#      'start_time': None,
#      'end_time': None},
#     'currency_id': 'ARS',
#     'exchange_rate': None,
#     'payment_method_prices': [],
#     'payment_method_type': 'TMP',
#     'regular_amount': None,
#     'type': 'standard',
#     'metadata': {}},
#    'available_quantity': 1,
#    'official_store_id': None,
#    'use_thumbnail_id': False,
#    'accepts_mercadopago': True,
#    'variation_filters': ['COLOR'],
#    'shipping': {'store_pick_up': False,
#     'free_shipping': True,
#     'logistic_type': 'xd_drop_off',
#     'mode': 'me2',
#     'tags': ['self_service_in', 'mandatory_free_shipping'],
#     'benefits': None,
#     'promise': None,
#     'shipping_score': -1},
#    'stop_time': '2044-08-17T04:00:00.000Z',
#    'seller': {'id': 1299783288, 'nickname': 'POWER_COMPUTERS'},
#    'attributes': [{'id': 'BRAND',
#      'name': 'Marca',
#      'value_id': '9344',
#      'value_name': 'Apple',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '9344',
#        'name': 'Apple',
#        'struct': None,
#        'source': 6402814585011704}],
#      'source': 6402814585011704,
#      'value_type': 'string'},
#     {'id': 'ITEM_CONDITION',
#      'name': 'Condición del ítem',
#      'value_id': '2230582',
#      'value_name': 'Reacondicionado',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '2230582',
#        'name': 'Reacondicionado',
#        'struct': None,
#        'source': 6402814585011704}],
#      'source': 6402814585011704,
#      'value_type': 'list'},
#     {'id': 'LINE',
#      'name': 'Línea',
#      'value_id': '13876686',
#      'value_name': 'iPhone 14',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '13876686',
#        'name': 'iPhone 14',
#        'struct': None,
#        'source': 6402814585011704}],
#      'source': 6402814585011704,
#      'value_type': 'string'},
#     {'id': 'MODEL',
#      'name': 'Modelo',
#      'value_id': '13188535',
#      'value_name': 'iPhone 14 Pro Max',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '13188535',
#        'name': 'iPhone 14 Pro Max',
#        'struct': None,
#        'source': 6402814585011704}],
#      'source': 6402814585011704,
#      'value_type': 'string'},
#     {'id': 'PROCESSOR_MODEL',
#      'name': 'Modelo del procesador',
#      'value_id': '13188555',
#      'value_name': 'Apple A16 Bionic',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '13188555',
#        'name': 'Apple A16 Bionic',
#        'struct': None,
#        'source': 6402814585011704}],
#      'source': 6402814585011704,
#      'value_type': 'string'},
#     {'id': 'WEIGHT',
#      'name': 'Peso',
#      'value_id': None,
#      'value_name': '240 g',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 240, 'unit': 'g'},
#      'values': [{'id': None,
#        'name': '240 g',
#        'struct': {'number': 240, 'unit': 'g'},
#        'source': 6402814585011704}],
#      'source': 6402814585011704,
#      'value_type': 'number_unit'}],
#    'variations_data': {'184445855981': {'thumbnail': 'http://http2.mlstatic.com/D_720140-MLA78622426123_082024-O.jpg',
#      'ratio': '0.80',
#      'name': 'Negro',
#      'pictures_qty': 9,
#      'price': 1720000,
#      'user_product_id': 'MLAU624589040',
#      'attributes': [{'id': 'MAIN_COLOR',
#        'name': 'Color principal',
#        'value_name': 'list',
#        'value_type': 'Negro'}],
#      'attribute_combinations': None}},
#    'installments': {'quantity': 6,
#     'amount': 398438,
#     'rate': 38.99,
#     'currency_id': 'ARS',
#     'metadata': {'meliplus_installments': False,
#      'additional_bank_interest': False}},
#    'winner_item_id': None,
#    'catalog_listing': False,
#    'discounts': None,
#    'promotions': [],
#    'inventory_id': None},
#   {'id': 'MLA1890309638',
#    'title': 'Apple iPhone 14 Pro Max (128 Gb) - Oro + 85% Bateria Usado',
#    'condition': 'new',
#    'thumbnail_id': '693479-MLA78390655944_082024',
#    'catalog_product_id': 'MLA19615313',
#    'listing_type_id': 'gold_special',
#    'sanitized_title': 'apple-iphone-14-pro-max-128-gb-oro-85-bateria-usado',
#    'permalink': 'https://articulo.mercadolibre.com.ar/MLA-1890309638-apple-iphone-14-pro-max-128-gb-oro-85-bateria-usado-_JM',
#    'buying_mode': 'buy_it_now',
#    'site_id': 'MLA',
#    'category_id': 'MLA1055',
#    'domain_id': 'MLA-CELLPHONES',
#    'variation_id': '184445349433',
#    'thumbnail': 'http://http2.mlstatic.com/D_693479-MLA78390655944_082024-O.jpg',
#    'currency_id': 'ARS',
#    'order_backend': 2,
#    'price': 1720000,
#    'original_price': None,
#    'sale_price': {'price_id': '',
#     'amount': 1720000,
#     'conditions': {'eligible': True,
#      'context_restrictions': ['channel_marketplace'],
#      'start_time': None,
#      'end_time': None},
#     'currency_id': 'ARS',
#     'exchange_rate': None,
#     'payment_method_prices': [],
#     'payment_method_type': 'TMP',
#     'regular_amount': None,
#     'type': 'standard',
#     'metadata': {}},
#    'available_quantity': 1,
#    'official_store_id': None,
#    'use_thumbnail_id': False,
#    'accepts_mercadopago': True,
#    'variation_filters': ['COLOR'],
#    'shipping': {'store_pick_up': False,
#     'free_shipping': True,
#     'logistic_type': 'xd_drop_off',
#     'mode': 'me2',
#     'tags': ['self_service_in', 'mandatory_free_shipping'],
#     'benefits': None,
#     'promise': None,
#     'shipping_score': -1},
#    'stop_time': '2044-08-17T04:00:00.000Z',
#    'seller': {'id': 1299783288, 'nickname': 'POWER_COMPUTERS'},
#    'attributes': [{'id': 'BRAND',
#      'name': 'Marca',
#      'value_id': '9344',
#      'value_name': 'Apple',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '9344',
#        'name': 'Apple',
#        'struct': None,
#        'source': 6402814585011704}],
#      'source': 6402814585011704,
#      'value_type': 'string'},
#     {'id': 'ITEM_CONDITION',
#      'name': 'Condición del ítem',
#      'value_id': '2230582',
#      'value_name': 'Reacondicionado',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '2230582',
#        'name': 'Reacondicionado',
#        'struct': None,
#        'source': 6402814585011704}],
#      'source': 6402814585011704,
#      'value_type': 'list'},
#     {'id': 'LINE',
#      'name': 'Línea',
#      'value_id': '13876686',
#      'value_name': 'iPhone 14',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '13876686',
#        'name': 'iPhone 14',
#        'struct': None,
#        'source': 6402814585011704}],
#      'source': 6402814585011704,
#      'value_type': 'string'},
#     {'id': 'MODEL',
#      'name': 'Modelo',
#      'value_id': '13188535',
#      'value_name': 'iPhone 14 Pro Max',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '13188535',
#        'name': 'iPhone 14 Pro Max',
#        'struct': None,
#        'source': 6402814585011704}],
#      'source': 6402814585011704,
#      'value_type': 'string'},
#     {'id': 'PROCESSOR_MODEL',
#      'name': 'Modelo del procesador',
#      'value_id': '13188555',
#      'value_name': 'Apple A16 Bionic',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '13188555',
#        'name': 'Apple A16 Bionic',
#        'struct': None,
#        'source': 6402814585011704}],
#      'source': 6402814585011704,
#      'value_type': 'string'},
#     {'id': 'WEIGHT',
#      'name': 'Peso',
#      'value_id': None,
#      'value_name': '240 g',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 240, 'unit': 'g'},
#      'values': [{'id': None,
#        'name': '240 g',
#        'struct': {'unit': 'g', 'number': 240},
#        'source': 6402814585011704}],
#      'source': 6402814585011704,
#      'value_type': 'number_unit'}],
#    'variations_data': {'184445349433': {'thumbnail': 'http://http2.mlstatic.com/D_693479-MLA78390655944_082024-O.jpg',
#      'ratio': '0.80',
#      'name': 'Dorado',
#      'pictures_qty': 7,
#      'price': 1720000,
#      'user_product_id': 'MLAU621321029',
#      'attributes': [{'id': 'MAIN_COLOR',
#        'name': 'Color principal',
#        'value_name': 'list',
#        'value_type': 'Dorado'}],
#      'attribute_combinations': None}},
#    'installments': {'quantity': 6,
#     'amount': 398438,
#     'rate': 38.99,
#     'currency_id': 'ARS',
#     'metadata': {'meliplus_installments': False,
#      'additional_bank_interest': False}},
#    'winner_item_id': None,
#    'catalog_listing': False,
#    'discounts': None,
#    'promotions': [],
#    'inventory_id': None},
#   {'id': 'MLA1452977585',
#    'title': 'Apple iPhone 14 Pro Max (1 Tb) - Negro Espacial Nuevo',
#    'condition': 'new',
#    'thumbnail_id': '953526-MLA79705988157_102024',
#    'catalog_product_id': 'MLA19615313',
#    'listing_type_id': 'free',
#    'sanitized_title': 'apple-iphone-14-pro-max-1-tb-negro-espacial-nuevo',
#    'permalink': 'https://articulo.mercadolibre.com.ar/MLA-1452977585-apple-iphone-14-pro-max-1-tb-negro-espacial-nuevo-_JM',
#    'buying_mode': 'buy_it_now',
#    'site_id': 'MLA',
#    'category_id': 'MLA1055',
#    'domain_id': 'MLA-CELLPHONES',
#    'variation_id': '181820262616',
#    'thumbnail': 'http://http2.mlstatic.com/D_953526-MLA79705988157_102024-O.jpg',
#    'currency_id': 'ARS',
#    'order_backend': 3,
#    'price': 1950000,
#    'original_price': None,
#    'sale_price': {'price_id': '',
#     'amount': 1950000,
#     'conditions': {'eligible': True,
#      'context_restrictions': [],
#      'start_time': None,
#      'end_time': None},
#     'currency_id': 'ARS',
#     'exchange_rate': None,
#     'payment_method_prices': [],
#     'payment_method_type': 'TMP',
#     'regular_amount': None,
#     'type': 'standard',
#     'metadata': {}},
#    'available_quantity': 1,
#    'official_store_id': None,
#    'use_thumbnail_id': False,
#    'accepts_mercadopago': True,
#    'variation_filters': ['COLOR'],
#    'shipping': {'store_pick_up': False,
#     'free_shipping': False,
#     'logistic_type': 'xd_drop_off',
#     'mode': 'me2',
#     'tags': ['local_pick_up_not_allowed'],
#     'benefits': None,
#     'promise': None,
#     'shipping_score': -1},
#    'stop_time': '2024-11-30T04:00:00.000Z',
#    'seller': {'id': 16001788, 'nickname': 'LICORES'},
#    'attributes': [{'id': 'BRAND',
#      'name': 'Marca',
#      'value_id': '9344',
#      'value_name': 'Apple',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '9344',
#        'name': 'Apple',
#        'struct': None,
#        'source': 6402814585011704}],
#      'source': 6402814585011704,
#      'value_type': 'string'},
#     {'id': 'ITEM_CONDITION',
#      'name': 'Condición del ítem',
#      'value_id': '2230284',
#      'value_name': 'Nuevo',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '2230284',
#        'name': 'Nuevo',
#        'struct': None,
#        'source': 6402814585011704}],
#      'source': 6402814585011704,
#      'value_type': 'list'},
#     {'id': 'LINE',
#      'name': 'Línea',
#      'value_id': '13876686',
#      'value_name': 'iPhone 14',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '13876686',
#        'name': 'iPhone 14',
#        'struct': None,
#        'source': 6402814585011704}],
#      'source': 6402814585011704,
#      'value_type': 'string'},
#     {'id': 'MODEL',
#      'name': 'Modelo',
#      'value_id': '13188535',
#      'value_name': 'iPhone 14 Pro Max',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '13188535',
#        'name': 'iPhone 14 Pro Max',
#        'struct': None,
#        'source': 6402814585011704}],
#      'source': 6402814585011704,
#      'value_type': 'string'},
#     {'id': 'PROCESSOR_MODEL',
#      'name': 'Modelo del procesador',
#      'value_id': '17931',
#      'value_name': 'A16',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '17931',
#        'name': 'A16',
#        'struct': None,
#        'source': 6402814585011704}],
#      'source': 6402814585011704,
#      'value_type': 'string'}],
#    'variations_data': {'181820262616': {'thumbnail': 'http://http2.mlstatic.com/D_953526-MLA79705988157_102024-O.jpg',
#      'ratio': '0.80',
#      'name': 'Space Grey',
#      'pictures_qty': 4,
#      'price': 1950000,
#      'user_product_id': 'MLAU1803101102',
#      'attributes': [{'id': 'GTIN',
#        'name': 'Código universal de producto',
#        'value_name': 'string',
#        'value_type': '194253382751'}],
#      'attribute_combinations': None}},
#    'installments': {'quantity': 6,
#     'amount': 451717.5,
#     'rate': 38.99,
#     'currency_id': 'ARS',
#     'metadata': {'meliplus_installments': False,
#      'additional_bank_interest': False}},
#    'winner_item_id': None,
#    'catalog_listing': False,
#    'discounts': None,
#    'promotions': [],
#    'inventory_id': None},
#   {'id': 'MLA1414395007',
#    'title': 'Apple iPhone 14 Pro Max 512gb Nuevo En Caja Sellada Silver',
#    'condition': 'new',
#    'thumbnail_id': '750456-MLA75104449307_032024',
#    'catalog_product_id': None,
#    'listing_type_id': 'gold_special',
#    'sanitized_title': 'apple-iphone-14-pro-max-512gb-nuevo-en-caja-sellada-silver',
#    'permalink': 'https://articulo.mercadolibre.com.ar/MLA-1414395007-apple-iphone-14-pro-max-512gb-nuevo-en-caja-sellada-silver-_JM',
#    'buying_mode': 'buy_it_now',
#    'site_id': 'MLA',
#    'category_id': 'MLA1055',
#    'domain_id': 'MLA-CELLPHONES',
#    'variation_id': '182067257499',
#    'thumbnail': 'http://http2.mlstatic.com/D_750456-MLA75104449307_032024-O.jpg',
#    'currency_id': 'ARS',
#    'order_backend': 4,
#    'price': 3000000,
#    'original_price': None,
#    'sale_price': {'price_id': '',
#     'amount': 3000000,
#     'conditions': {'eligible': True,
#      'context_restrictions': [],
#      'start_time': None,
#      'end_time': None},
#     'currency_id': 'ARS',
#     'exchange_rate': None,
#     'payment_method_prices': [],
#     'payment_method_type': 'TMP',
#     'regular_amount': None,
#     'type': 'standard',
#     'metadata': {}},
#    'available_quantity': 1,
#    'official_store_id': None,
#    'use_thumbnail_id': False,
#    'accepts_mercadopago': True,
#    'variation_filters': ['COLOR'],
#    'shipping': {'store_pick_up': False,
#     'free_shipping': True,
#     'logistic_type': 'xd_drop_off',
#     'mode': 'me2',
#     'tags': ['local_pick_up_not_allowed', 'mandatory_free_shipping'],
#     'benefits': None,
#     'promise': None,
#     'shipping_score': -1},
#    'stop_time': '2044-03-08T04:00:00.000Z',
#    'seller': {'id': 70718068, 'nickname': 'CAROTODOVUELVE'},
#    'attributes': [{'id': 'BRAND',
#      'name': 'Marca',
#      'value_id': '9344',
#      'value_name': 'Apple',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '9344',
#        'name': 'Apple',
#        'struct': None,
#        'source': 7092}],
#      'source': 7092,
#      'value_type': 'string'},
#     {'id': 'ITEM_CONDITION',
#      'name': 'Condición del ítem',
#      'value_id': '2230284',
#      'value_name': 'Nuevo',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '2230284',
#        'name': 'Nuevo',
#        'struct': None,
#        'source': 7092}],
#      'source': 7092,
#      'value_type': 'list'},
#     {'id': 'LINE',
#      'name': 'Línea',
#      'value_id': '13876686',
#      'value_name': 'iPhone 14',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '13876686',
#        'name': 'iPhone 14',
#        'struct': None,
#        'source': 1000427007642219}],
#      'source': 1000427007642219,
#      'value_type': 'string'},
#     {'id': 'MODEL',
#      'name': 'Modelo',
#      'value_id': None,
#      'value_name': 'I Phone Pro Max',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': None,
#        'name': 'I Phone Pro Max',
#        'struct': None,
#        'source': 7092}],
#      'source': 7092,
#      'value_type': 'string'}],
#    'variations_data': {'182067257499': {'thumbnail': 'http://http2.mlstatic.com/D_750456-MLA75104449307_032024-O.jpg',
#      'ratio': '0.81',
#      'name': 'Plateado',
#      'pictures_qty': 6,
#      'price': 3000000,
#      'user_product_id': 'MLAU336505394',
#      'attributes': [{'id': 'GTIN',
#        'name': 'Código universal de producto',
#        'value_name': 'string',
#        'value_type': '194253378860'}],
#      'attribute_combinations': None}},
#    'installments': {'quantity': 6,
#     'amount': 694950,
#     'rate': 38.99,
#     'currency_id': 'ARS',
#     'metadata': {'meliplus_installments': False,
#      'additional_bank_interest': False}},
#    'winner_item_id': None,
#    'catalog_listing': False,
#    'discounts': None,
#    'promotions': [],
#    'inventory_id': None},
#   {'id': 'MLA1870249594',
#    'title': "iPhone 14 Pro Max 128gb - 5g - 6gb Ram - Pantalla 6,7''",
#    'condition': 'new',
#    'thumbnail_id': '789899-MLA77922315196_082024',
#    'catalog_product_id': None,
#    'listing_type_id': 'gold_special',
#    'sanitized_title': 'iphone-14-pro-max-128gb-5g-6gb-ram-pantalla-67',
#    'permalink': 'https://articulo.mercadolibre.com.ar/MLA-1870249594-iphone-14-pro-max-128gb-5g-6gb-ram-pantalla-67-_JM',
#    'buying_mode': 'buy_it_now',
#    'site_id': 'MLA',
#    'category_id': 'MLA1055',
#    'domain_id': 'MLA-CELLPHONES',
#    'variation_id': '181260465120',
#    'thumbnail': 'http://http2.mlstatic.com/D_789899-MLA77922315196_082024-O.jpg',
#    'currency_id': 'ARS',
#    'order_backend': 5,
#    'price': 2320000,
#    'original_price': None,
#    'sale_price': {'price_id': '',
#     'amount': 2320000,
#     'conditions': {'eligible': True,
#      'context_restrictions': [],
#      'start_time': None,
#      'end_time': None},
#     'currency_id': 'ARS',
#     'exchange_rate': None,
#     'payment_method_prices': [],
#     'payment_method_type': 'TMP',
#     'regular_amount': None,
#     'type': 'standard',
#     'metadata': {}},
#    'available_quantity': 1,
#    'official_store_id': None,
#    'use_thumbnail_id': False,
#    'accepts_mercadopago': True,
#    'variation_filters': ['COLOR'],
#    'shipping': {'store_pick_up': False,
#     'free_shipping': True,
#     'logistic_type': 'xd_drop_off',
#     'mode': 'me2',
#     'tags': ['local_pick_up_not_allowed', 'mandatory_free_shipping'],
#     'benefits': None,
#     'promise': None,
#     'shipping_score': -1},
#    'stop_time': '2044-07-28T04:00:00.000Z',
#    'seller': {'id': 1916664794, 'nickname': 'BLACKCOUNTDOWN'},
#    'attributes': [{'id': 'BRAND',
#      'name': 'Marca',
#      'value_id': '9344',
#      'value_name': 'Apple',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '9344',
#        'name': 'Apple',
#        'struct': None,
#        'source': 6402814585011704}],
#      'source': 6402814585011704,
#      'value_type': 'string'},
#     {'id': 'ITEM_CONDITION',
#      'name': 'Condición del ítem',
#      'value_id': '2230284',
#      'value_name': 'Nuevo',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '2230284',
#        'name': 'Nuevo',
#        'struct': None,
#        'source': 6402814585011704}],
#      'source': 6402814585011704,
#      'value_type': 'list'},
#     {'id': 'LINE',
#      'name': 'Línea',
#      'value_id': '13876686',
#      'value_name': 'iPhone 14',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '13876686',
#        'name': 'iPhone 14',
#        'struct': None,
#        'source': 6402814585011704}],
#      'source': 6402814585011704,
#      'value_type': 'string'},
#     {'id': 'MODEL',
#      'name': 'Modelo',
#      'value_id': None,
#      'value_name': '14 pro max 128gb',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': None,
#        'name': '14 pro max 128gb',
#        'struct': None,
#        'source': 6402814585011704}],
#      'source': 6402814585011704,
#      'value_type': 'string'},
#     {'id': 'PROCESSOR_MODEL',
#      'name': 'Modelo del procesador',
#      'value_id': None,
#      'value_name': 'A16 Bionic',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': None,
#        'name': 'A16 Bionic',
#        'struct': None,
#        'source': 6402814585011704}],
#      'source': 6402814585011704,
#      'value_type': 'string'},
#     {'id': 'WEIGHT',
#      'name': 'Peso',
#      'value_id': None,
#      'value_name': '206 g',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 206, 'unit': 'g'},
#      'values': [{'id': None,
#        'name': '206 g',
#        'struct': {'number': 206, 'unit': 'g'},
#        'source': 6402814585011704}],
#      'source': 6402814585011704,
#      'value_type': 'number_unit'}],
#    'variations_data': {'181260465120': {'thumbnail': 'http://http2.mlstatic.com/D_789899-MLA77922315196_082024-O.jpg',
#      'ratio': '0.81',
#      'name': 'Dorado',
#      'pictures_qty': 5,
#      'price': 2320000,
#      'user_product_id': 'MLAU436043786',
#      'attributes': [{'id': 'MAIN_COLOR',
#        'name': 'Color principal',
#        'value_name': 'list',
#        'value_type': 'Dorado'},
#       {'id': 'GTIN',
#        'name': 'Código universal de producto',
#        'value_name': 'string',
#        'value_type': '0123456789012'}],
#      'attribute_combinations': None},
#     '181260465122': {'thumbnail': 'http://http2.mlstatic.com/D_678167-MLA78145280641_082024-O.jpg',
#      'ratio': '0.81',
#      'name': 'Morado',
#      'pictures_qty': 6,
#      'price': 2320000,
#      'user_product_id': 'MLAU436043790',
#      'attributes': [{'id': 'GTIN',
#        'name': 'Código universal de producto',
#        'value_name': 'string',
#        'value_type': '0123456789012'}],
#      'attribute_combinations': None},
#     '181260465124': {'thumbnail': 'http://http2.mlstatic.com/D_875880-MLA78145300807_082024-O.jpg',
#      'ratio': '0.81',
#      'name': 'Negro',
#      'pictures_qty': 5,
#      'price': 2320000,
#      'user_product_id': 'MLAU434170397',
#      'attributes': [{'id': 'MAIN_COLOR',
#        'name': 'Color principal',
#        'value_name': 'list',
#        'value_type': 'Negro'},
#       {'id': 'GTIN',
#        'name': 'Código universal de producto',
#        'value_name': 'string',
#        'value_type': '0123456789012'}],
#      'attribute_combinations': None},
#     '181260465126': {'thumbnail': 'http://http2.mlstatic.com/D_919917-MLA77922286238_082024-O.jpg',
#      'ratio': '0.81',
#      'name': 'Plateado',
#      'pictures_qty': 5,
#      'price': 2320000,
#      'user_product_id': 'MLAU434172253',
#      'attributes': [{'id': 'MAIN_COLOR',
#        'name': 'Color principal',
#        'value_name': 'list',
#        'value_type': 'Plateado'},
#       {'id': 'GTIN',
#        'name': 'Código universal de producto',
#        'value_name': 'string',
#        'value_type': '0123456789012'}],
#      'attribute_combinations': None}},
#    'installments': {'quantity': 6,
#     'amount': 537428,
#     'rate': 38.99,
#     'currency_id': 'ARS',
#     'metadata': {'meliplus_installments': False,
#      'additional_bank_interest': False}},
#    'winner_item_id': None,
#    'catalog_listing': False,
#    'discounts': None,
#    'promotions': [],
#    'inventory_id': None},
#   {'id': 'MLA1889892184',
#    'title': 'Celular Apple 14 Pro Max Nuevo De 512 Gb Garantia Local',
#    'condition': 'new',
#    'thumbnail_id': '704221-MLA78366719252_082024',
#    'catalog_product_id': None,
#    'listing_type_id': 'gold_special',
#    'sanitized_title': 'celular-apple-14-pro-max-nuevo-de-512-gb-garantia-local',
#    'permalink': 'https://articulo.mercadolibre.com.ar/MLA-1889892184-celular-apple-14-pro-max-nuevo-de-512-gb-garantia-local-_JM',
#    'buying_mode': 'buy_it_now',
#    'site_id': 'MLA',
#    'category_id': 'MLA1055',
#    'domain_id': 'MLA-CELLPHONES',
#    'variation_id': '184424423403',
#    'thumbnail': 'http://http2.mlstatic.com/D_704221-MLA78366719252_082024-O.jpg',
#    'currency_id': 'ARS',
#    'order_backend': 6,
#    'price': 1890000,
#    'original_price': None,
#    'sale_price': {'price_id': '',
#     'amount': 1890000,
#     'conditions': {'eligible': True,
#      'context_restrictions': [],
#      'start_time': None,
#      'end_time': None},
#     'currency_id': 'ARS',
#     'exchange_rate': None,
#     'payment_method_prices': [],
#     'payment_method_type': 'TMP',
#     'regular_amount': None,
#     'type': 'standard',
#     'metadata': {}},
#    'available_quantity': 1,
#    'official_store_id': None,
#    'use_thumbnail_id': False,
#    'accepts_mercadopago': True,
#    'variation_filters': ['COLOR'],
#    'shipping': {'store_pick_up': False,
#     'free_shipping': True,
#     'logistic_type': 'xd_drop_off',
#     'mode': 'me2',
#     'tags': ['local_pick_up_not_allowed', 'mandatory_free_shipping'],
#     'benefits': None,
#     'promise': None,
#     'shipping_score': -1},
#    'stop_time': '2044-08-16T04:00:00.000Z',
#    'seller': {'id': 1946164845, 'nickname': 'FM20240815130536'},
#    'attributes': [{'id': 'BRAND',
#      'name': 'Marca',
#      'value_id': '9344',
#      'value_name': 'Apple',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '9344',
#        'name': 'Apple',
#        'struct': None,
#        'source': 6402814585011704}],
#      'source': 6402814585011704,
#      'value_type': 'string'},
#     {'id': 'ITEM_CONDITION',
#      'name': 'Condición del ítem',
#      'value_id': '2230284',
#      'value_name': 'Nuevo',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '2230284',
#        'name': 'Nuevo',
#        'struct': None,
#        'source': 6402814585011704}],
#      'source': 6402814585011704,
#      'value_type': 'list'},
#     {'id': 'LINE',
#      'name': 'Línea',
#      'value_id': '13876686',
#      'value_name': 'iPhone 14',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '13876686',
#        'name': 'iPhone 14',
#        'struct': None,
#        'source': 6402814585011704}],
#      'source': 6402814585011704,
#      'value_type': 'string'},
#     {'id': 'MODEL',
#      'name': 'Modelo',
#      'value_id': '13188535',
#      'value_name': 'iPhone 14 Pro Max',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '13188535',
#        'name': 'iPhone 14 Pro Max',
#        'struct': None,
#        'source': 6402814585011704}],
#      'source': 6402814585011704,
#      'value_type': 'string'}],
#    'variations_data': {'184424423403': {'thumbnail': 'http://http2.mlstatic.com/D_704221-MLA78366719252_082024-O.jpg',
#      'ratio': '0.93',
#      'name': 'Dorado',
#      'pictures_qty': 1,
#      'price': 1890000,
#      'user_product_id': 'MLAU604203010',
#      'attributes': [{'id': 'MAIN_COLOR',
#        'name': 'Color principal',
#        'value_name': 'list',
#        'value_type': 'Dorado'},
#       {'id': 'GTIN',
#        'name': 'Código universal de producto',
#        'value_name': 'string',
#        'value_type': '190198457349'}],
#      'attribute_combinations': None}},
#    'installments': {'quantity': 6,
#     'amount': 437818.5,
#     'rate': 38.99,
#     'currency_id': 'ARS',
#     'metadata': {'meliplus_installments': False,
#      'additional_bank_interest': False}},
#    'winner_item_id': None,
#    'catalog_listing': False,
#    'discounts': None,
#    'promotions': [],
#    'inventory_id': None},
#   {'id': 'MLA1853088714',
#    'title': 'Celular iPhone 14 Pro Max Nuevo De 128gb Caja Envios',
#    'condition': 'new',
#    'thumbnail_id': '963382-MLA77624616420_072024',
#    'catalog_product_id': None,
#    'listing_type_id': 'gold_special',
#    'sanitized_title': 'celular-iphone-14-pro-max-nuevo-de-128gb-caja-envios',
#    'permalink': 'https://articulo.mercadolibre.com.ar/MLA-1853088714-celular-iphone-14-pro-max-nuevo-de-128gb-caja-envios-_JM',
#    'buying_mode': 'buy_it_now',
#    'site_id': 'MLA',
#    'category_id': 'MLA1055',
#    'domain_id': 'MLA-CELLPHONES',
#    'variation_id': '181139737126',
#    'thumbnail': 'http://http2.mlstatic.com/D_963382-MLA77624616420_072024-O.jpg',
#    'currency_id': 'ARS',
#    'order_backend': 7,
#    'price': 1891000,
#    'original_price': None,
#    'sale_price': {'price_id': '',
#     'amount': 1891000,
#     'conditions': {'eligible': True,
#      'context_restrictions': [],
#      'start_time': None,
#      'end_time': None},
#     'currency_id': 'ARS',
#     'exchange_rate': None,
#     'payment_method_prices': [],
#     'payment_method_type': 'TMP',
#     'regular_amount': None,
#     'type': 'standard',
#     'metadata': {}},
#    'available_quantity': 1,
#    'official_store_id': None,
#    'use_thumbnail_id': False,
#    'accepts_mercadopago': True,
#    'variation_filters': ['COLOR'],
#    'shipping': {'store_pick_up': False,
#     'free_shipping': True,
#     'logistic_type': 'xd_drop_off',
#     'mode': 'me2',
#     'tags': ['local_pick_up_not_allowed', 'mandatory_free_shipping'],
#     'benefits': None,
#     'promise': None,
#     'shipping_score': -1},
#    'stop_time': '2044-07-15T04:00:00.000Z',
#    'seller': {'id': 1907458519, 'nickname': 'SR20240719161858'},
#    'attributes': [{'id': 'BRAND',
#      'name': 'Marca',
#      'value_id': '9344',
#      'value_name': 'Apple',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '9344',
#        'name': 'Apple',
#        'struct': None,
#        'source': 6402814585011704}],
#      'source': 6402814585011704,
#      'value_type': 'string'},
#     {'id': 'ITEM_CONDITION',
#      'name': 'Condición del ítem',
#      'value_id': '2230284',
#      'value_name': 'Nuevo',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '2230284',
#        'name': 'Nuevo',
#        'struct': None,
#        'source': 6402814585011704}],
#      'source': 6402814585011704,
#      'value_type': 'list'},
#     {'id': 'LINE',
#      'name': 'Línea',
#      'value_id': '13876686',
#      'value_name': 'iPhone 14',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '13876686',
#        'name': 'iPhone 14',
#        'struct': None,
#        'source': 6402814585011704}],
#      'source': 6402814585011704,
#      'value_type': 'string'},
#     {'id': 'MODEL',
#      'name': 'Modelo',
#      'value_id': '13188535',
#      'value_name': 'iPhone 14 Pro Max',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '13188535',
#        'name': 'iPhone 14 Pro Max',
#        'struct': None,
#        'source': 6402814585011704}],
#      'source': 6402814585011704,
#      'value_type': 'string'}],
#    'variations_data': {'181139737126': {'thumbnail': 'http://http2.mlstatic.com/D_963382-MLA77624616420_072024-O.jpg',
#      'ratio': '1.33',
#      'name': 'Negro',
#      'pictures_qty': 1,
#      'price': 1891000,
#      'user_product_id': 'MLAU412905552',
#      'attributes': [{'id': 'MAIN_COLOR',
#        'name': 'Color principal',
#        'value_name': 'list',
#        'value_type': 'Negro'},
#       {'id': 'GTIN',
#        'name': 'Código universal de producto',
#        'value_name': 'string',
#        'value_type': '194252786239'}],
#      'attribute_combinations': None}},
#    'installments': {'quantity': 6,
#     'amount': 438050.15,
#     'rate': 38.99,
#     'currency_id': 'ARS',
#     'metadata': {'meliplus_installments': False,
#      'additional_bank_interest': False}},
#    'winner_item_id': None,
#    'catalog_listing': False,
#    'discounts': None,
#    'promotions': [],
#    'inventory_id': None},
#   {'id': 'MLA1889993976',
#    'title': 'Celular Apple 14 Pro Max Nuevo De 128gb Entrega Inmediata',
#    'condition': 'new',
#    'thumbnail_id': '934067-MLA78366757376_082024',
#    'catalog_product_id': None,
#    'listing_type_id': 'gold_special',
#    'sanitized_title': 'celular-apple-14-pro-max-nuevo-de-128gb-entrega-inmediata',
#    'permalink': 'https://articulo.mercadolibre.com.ar/MLA-1889993976-celular-apple-14-pro-max-nuevo-de-128gb-entrega-inmediata-_JM',
#    'buying_mode': 'buy_it_now',
#    'site_id': 'MLA',
#    'category_id': 'MLA1055',
#    'domain_id': 'MLA-CELLPHONES',
#    'variation_id': '184424375033',
#    'thumbnail': 'http://http2.mlstatic.com/D_934067-MLA78366757376_082024-O.jpg',
#    'currency_id': 'ARS',
#    'order_backend': 8,
#    'price': 1890000,
#    'original_price': None,
#    'sale_price': {'price_id': '',
#     'amount': 1890000,
#     'conditions': {'eligible': True,
#      'context_restrictions': [],
#      'start_time': None,
#      'end_time': None},
#     'currency_id': 'ARS',
#     'exchange_rate': None,
#     'payment_method_prices': [],
#     'payment_method_type': 'TMP',
#     'regular_amount': None,
#     'type': 'standard',
#     'metadata': {}},
#    'available_quantity': 1,
#    'official_store_id': None,
#    'use_thumbnail_id': False,
#    'accepts_mercadopago': True,
#    'variation_filters': ['COLOR'],
#    'shipping': {'store_pick_up': False,
#     'free_shipping': True,
#     'logistic_type': 'xd_drop_off',
#     'mode': 'me2',
#     'tags': ['local_pick_up_not_allowed', 'mandatory_free_shipping'],
#     'benefits': None,
#     'promise': None,
#     'shipping_score': -1},
#    'stop_time': '2044-08-16T04:00:00.000Z',
#    'seller': {'id': 1946164845, 'nickname': 'FM20240815130536'},
#    'attributes': [{'id': 'BRAND',
#      'name': 'Marca',
#      'value_id': '9344',
#      'value_name': 'Apple',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '9344',
#        'name': 'Apple',
#        'struct': None,
#        'source': 6402814585011704}],
#      'source': 6402814585011704,
#      'value_type': 'string'},
#     {'id': 'ITEM_CONDITION',
#      'name': 'Condición del ítem',
#      'value_id': '2230284',
#      'value_name': 'Nuevo',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '2230284',
#        'name': 'Nuevo',
#        'struct': None,
#        'source': 6402814585011704}],
#      'source': 6402814585011704,
#      'value_type': 'list'},
#     {'id': 'LINE',
#      'name': 'Línea',
#      'value_id': '13876686',
#      'value_name': 'iPhone 14',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '13876686',
#        'name': 'iPhone 14',
#        'struct': None,
#        'source': 6402814585011704}],
#      'source': 6402814585011704,
#      'value_type': 'string'},
#     {'id': 'MODEL',
#      'name': 'Modelo',
#      'value_id': '13188535',
#      'value_name': 'iPhone 14 Pro Max',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '13188535',
#        'name': 'iPhone 14 Pro Max',
#        'struct': None,
#        'source': 6402814585011704}],
#      'source': 6402814585011704,
#      'value_type': 'string'},
#     {'id': 'PROCESSOR_MODEL',
#      'name': 'Modelo del procesador',
#      'value_id': '6936434',
#      'value_name': 'Apple A11 Bionic',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '6936434',
#        'name': 'Apple A11 Bionic',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'value_type': 'string'},
#     {'id': 'WEIGHT',
#      'name': 'Peso',
#      'value_id': None,
#      'value_name': '174 g',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 174, 'unit': 'g'},
#      'values': [{'id': None,
#        'name': '174 g',
#        'struct': {'number': 174, 'unit': 'g'},
#        'source': 1}],
#      'source': 1,
#      'value_type': 'number_unit'}],
#    'variations_data': {'184424375033': {'thumbnail': 'http://http2.mlstatic.com/D_934067-MLA78366757376_082024-O.jpg',
#      'ratio': '0.80',
#      'name': 'Negro',
#      'pictures_qty': 1,
#      'price': 1890000,
#      'user_product_id': 'MLAU601607273',
#      'attributes': [{'id': 'MAIN_COLOR',
#        'name': 'Color principal',
#        'value_name': 'list',
#        'value_type': 'Negro'},
#       {'id': 'GTIN',
#        'name': 'Código universal de producto',
#        'value_name': 'string',
#        'value_type': '190198457349'}],
#      'attribute_combinations': None}},
#    'installments': {'quantity': 6,
#     'amount': 437818.5,
#     'rate': 38.99,
#     'currency_id': 'ARS',
#     'metadata': {'meliplus_installments': False,
#      'additional_bank_interest': False}},
#    'winner_item_id': None,
#    'catalog_listing': False,
#    'discounts': None,
#    'promotions': [],
#    'inventory_id': None},
#   {'id': 'MLA1385783071',
#    'title': 'Apple iPhone 14 Pro Max (128 Gb) Gold - Oro - Dual Sim - Usa',
#    'condition': 'new',
#    'thumbnail_id': '737907-MLA71425399949_082023',
#    'catalog_product_id': None,
#    'listing_type_id': 'gold_special',
#    'sanitized_title': '',
#    'permalink': 'https://articulo.mercadolibre.com.ar/MLA-1385783071-apple-iphone-14-pro-max-128-gb-gold-oro-dual-sim-usa-_JM',
#    'buying_mode': 'buy_it_now',
#    'site_id': 'MLA',
#    'category_id': 'MLA1055',
#    'domain_id': 'MLA-CELLPHONES',
#    'variation_id': '179677130715',
#    'thumbnail': 'http://http2.mlstatic.com/D_737907-MLA71425399949_082023-O.jpg',
#    'currency_id': 'ARS',
#    'order_backend': 9,
#    'price': 3399999,
#    'original_price': None,
#    'sale_price': {'price_id': '',
#     'amount': 3399999,
#     'conditions': {'eligible': True,
#      'context_restrictions': [],
#      'start_time': None,
#      'end_time': None},
#     'currency_id': 'ARS',
#     'exchange_rate': None,
#     'payment_method_prices': [],
#     'payment_method_type': 'TMP',
#     'regular_amount': None,
#     'type': 'standard',
#     'metadata': {}},
#    'available_quantity': 1,
#    'official_store_id': None,
#    'use_thumbnail_id': False,
#    'accepts_mercadopago': True,
#    'variation_filters': ['COLOR'],
#    'shipping': {'store_pick_up': False,
#     'free_shipping': True,
#     'logistic_type': 'drop_off',
#     'mode': 'me2',
#     'tags': ['mandatory_free_shipping'],
#     'benefits': None,
#     'promise': None,
#     'shipping_score': -1},
#    'stop_time': '2043-08-26T04:00:00.000Z',
#    'seller': {'id': 1230468197, 'nickname': 'NUTRICOLOGY'},
#    'attributes': [{'id': 'BRAND',
#      'name': 'Marca',
#      'value_id': '9344',
#      'value_name': 'Apple',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '9344',
#        'name': 'Apple',
#        'struct': None,
#        'source': 2860837171021627}],
#      'source': 2860837171021627,
#      'value_type': 'string'},
#     {'id': 'GTIN',
#      'name': 'Código universal de producto',
#      'value_id': None,
#      'value_name': '857268005342',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': None,
#        'name': '857268005342',
#        'struct': None,
#        'source': 2860837171021627}],
#      'source': 2860837171021627,
#      'value_type': 'string'},
#     {'id': 'ITEM_CONDITION',
#      'name': 'Condición del ítem',
#      'value_id': '2230284',
#      'value_name': 'Nuevo',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '2230284',
#        'name': 'Nuevo',
#        'struct': None,
#        'source': 2860837171021627}],
#      'source': 2860837171021627,
#      'value_type': 'list'},
#     {'id': 'LINE',
#      'name': 'Línea',
#      'value_id': '13876686',
#      'value_name': 'iPhone 14',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '13876686',
#        'name': 'iPhone 14',
#        'struct': None,
#        'source': 2579503448603610}],
#      'source': 2579503448603610,
#      'value_type': 'string'},
#     {'id': 'MODEL',
#      'name': 'Modelo',
#      'value_id': '13188535',
#      'value_name': 'iPhone 14 Pro Max',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '13188535',
#        'name': 'iPhone 14 Pro Max',
#        'struct': None,
#        'source': 3942444344910321}],
#      'source': 3942444344910321,
#      'value_type': 'string'},
#     {'id': 'PROCESSOR_MODEL',
#      'name': 'Modelo del procesador',
#      'value_id': '13188555',
#      'value_name': 'Apple A16 Bionic',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '13188555',
#        'name': 'Apple A16 Bionic',
#        'struct': None,
#        'source': 3942444344910321}],
#      'source': 3942444344910321,
#      'value_type': 'string'},
#     {'id': 'WEIGHT',
#      'name': 'Peso',
#      'value_id': None,
#      'value_name': '240 g',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 240, 'unit': 'g'},
#      'values': [{'id': None,
#        'name': '240 g',
#        'struct': {'unit': 'g', 'number': 240},
#        'source': 3942444344910321}],
#      'source': 3942444344910321,
#      'value_type': 'number_unit'}],
#    'variations_data': {'179677130715': {'thumbnail': 'http://http2.mlstatic.com/D_737907-MLA71425399949_082023-O.jpg',
#      'ratio': '0.88',
#      'name': 'Oro',
#      'pictures_qty': 4,
#      'price': 3399999,
#      'user_product_id': 'MLAU256518807',
#      'attributes': [],
#      'attribute_combinations': None}},
#    'installments': {'quantity': 6,
#     'amount': 787609.77,
#     'rate': 38.99,
#     'currency_id': 'ARS',
#     'metadata': {'meliplus_installments': False,
#      'additional_bank_interest': False}},
#    'winner_item_id': None,
#    'catalog_listing': False,
#    'discounts': None,
#    'promotions': [],
#    'inventory_id': None},
#   {'id': 'MLA1490056284',
#    'title': 'Apple iPhone 14 Pro Max (128 Gb) - Negro - Dual Sim - Usa',
#    'condition': 'new',
#    'thumbnail_id': '856715-MLA71381558194_082023',
#    'catalog_product_id': None,
#    'listing_type_id': 'gold_special',
#    'sanitized_title': 'apple-iphone-14-pro-max-128-gb-negro-dual-sim-usa',
#    'permalink': 'https://articulo.mercadolibre.com.ar/MLA-1490056284-apple-iphone-14-pro-max-128-gb-negro-dual-sim-usa-_JM',
#    'buying_mode': 'buy_it_now',
#    'site_id': 'MLA',
#    'category_id': 'MLA1055',
#    'domain_id': 'MLA-CELLPHONES',
#    'variation_id': '178621906244',
#    'thumbnail': 'http://http2.mlstatic.com/D_856715-MLA71381558194_082023-O.jpg',
#    'currency_id': 'ARS',
#    'order_backend': 10,
#    'price': 3399999,
#    'original_price': None,
#    'sale_price': {'price_id': '',
#     'amount': 3399999,
#     'conditions': {'eligible': True,
#      'context_restrictions': [],
#      'start_time': None,
#      'end_time': None},
#     'currency_id': 'ARS',
#     'exchange_rate': None,
#     'payment_method_prices': [],
#     'payment_method_type': 'TMP',
#     'regular_amount': None,
#     'type': 'standard',
#     'metadata': {}},
#    'available_quantity': 1,
#    'official_store_id': None,
#    'use_thumbnail_id': False,
#    'accepts_mercadopago': True,
#    'variation_filters': ['COLOR'],
#    'shipping': {'store_pick_up': False,
#     'free_shipping': True,
#     'logistic_type': 'drop_off',
#     'mode': 'me2',
#     'tags': ['mandatory_free_shipping'],
#     'benefits': None,
#     'promise': None,
#     'shipping_score': -1},
#    'stop_time': '2043-08-26T04:00:00.000Z',
#    'seller': {'id': 1230468197, 'nickname': 'NUTRICOLOGY'},
#    'attributes': [{'id': 'BRAND',
#      'name': 'Marca',
#      'value_id': '9344',
#      'value_name': 'Apple',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '9344',
#        'name': 'Apple',
#        'struct': None,
#        'source': 2860837171021627}],
#      'source': 2860837171021627,
#      'value_type': 'string'},
#     {'id': 'GTIN',
#      'name': 'Código universal de producto',
#      'value_id': None,
#      'value_name': '857268005342',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': None,
#        'name': '857268005342',
#        'struct': None,
#        'source': 2860837171021627}],
#      'source': 2860837171021627,
#      'value_type': 'string'},
#     {'id': 'ITEM_CONDITION',
#      'name': 'Condición del ítem',
#      'value_id': '2230284',
#      'value_name': 'Nuevo',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '2230284',
#        'name': 'Nuevo',
#        'struct': None,
#        'source': 2860837171021627}],
#      'source': 2860837171021627,
#      'value_type': 'list'},
#     {'id': 'LINE',
#      'name': 'Línea',
#      'value_id': '13876686',
#      'value_name': 'iPhone 14',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '13876686',
#        'name': 'iPhone 14',
#        'struct': None,
#        'source': 2579503448603610}],
#      'source': 2579503448603610,
#      'value_type': 'string'},
#     {'id': 'MODEL',
#      'name': 'Modelo',
#      'value_id': '13188535',
#      'value_name': 'iPhone 14 Pro Max',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '13188535',
#        'name': 'iPhone 14 Pro Max',
#        'struct': None,
#        'source': 3942444344910321}],
#      'source': 3942444344910321,
#      'value_type': 'string'},
#     {'id': 'PROCESSOR_MODEL',
#      'name': 'Modelo del procesador',
#      'value_id': '13188555',
#      'value_name': 'Apple A16 Bionic',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '13188555',
#        'name': 'Apple A16 Bionic',
#        'struct': None,
#        'source': 3942444344910321}],
#      'source': 3942444344910321,
#      'value_type': 'string'},
#     {'id': 'WEIGHT',
#      'name': 'Peso',
#      'value_id': None,
#      'value_name': '240 g',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 240, 'unit': 'g'},
#      'values': [{'id': None,
#        'name': '240 g',
#        'struct': {'unit': 'g', 'number': 240},
#        'source': 3942444344910321}],
#      'source': 3942444344910321,
#      'value_type': 'number_unit'}],
#    'variations_data': {'178621906244': {'thumbnail': 'http://http2.mlstatic.com/D_856715-MLA71381558194_082023-O.jpg',
#      'ratio': '0.80',
#      'name': 'Negro espacial',
#      'pictures_qty': 6,
#      'price': 3399999,
#      'user_product_id': 'MLAU244710778',
#      'attributes': [{'id': 'MAIN_COLOR',
#        'name': 'Color principal',
#        'value_name': 'list',
#        'value_type': 'Negro'}],
#      'attribute_combinations': None}},
# ...
#      'source': 6288553339613210,
#      'value_type': 'string'},
#     {'id': 'PROCESSOR_MODEL',
#      'name': 'Modelo del procesador',
#      'value_id': '13188555',
#      'value_name': 'Apple A16 Bionic',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '13188555',
#        'name': 'Apple A16 Bionic',
#        'struct': None,
#        'source': 6288553339613210}],
#      'source': 6288553339613210,
#      'value_type': 'string'},
#     {'id': 'WEIGHT',
#      'name': 'Peso',
#      'value_id': None,
#      'value_name': '240 g',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 240, 'unit': 'g'},
#      'values': [{'id': None,
#        'name': '240 g',
#        'struct': {'number': 240, 'unit': 'g'},
#        'source': 6288553339613210}],
#      'source': 6288553339613210,
#      'value_type': 'number_unit'}],
#    'variations_data': {'181365641074': {'thumbnail': 'http://http2.mlstatic.com/D_989777-MLA78405725871_082024-O.jpg',
#      'ratio': '1.78',
#      'name': 'Beige',
#      'pictures_qty': 3,
#      'price': 1500000,
#      'user_product_id': 'MLAU454569468',
#      'attributes': [{'id': 'MAIN_COLOR',
#        'name': 'Color principal',
#        'value_name': 'list',
#        'value_type': 'Dorado'}],
#      'attribute_combinations': None}},
#    'installments': {'quantity': 6,
#     'amount': 347475,
#     'rate': 38.99,
#     'currency_id': 'ARS',
#     'metadata': {'meliplus_installments': False,
#      'additional_bank_interest': False}},
#    'winner_item_id': None,
#    'catalog_listing': False,
#    'discounts': None,
#    'promotions': [],
#    'inventory_id': None},
#   {'id': 'MLA1454867903',
#    'title': 'iPhone 14 Pro Max 128 Gb Usado',
#    'condition': 'used',
#    'thumbnail_id': '989376-MLA79913908993_102024',
#    'catalog_product_id': 'MLA19615313',
#    'listing_type_id': 'gold_pro',
#    'sanitized_title': 'iphone-14-pro-max-128-gb-usado',
#    'permalink': 'https://articulo.mercadolibre.com.ar/MLA-1454867903-iphone-14-pro-max-128-gb-usado-_JM',
#    'buying_mode': 'buy_it_now',
#    'site_id': 'MLA',
#    'category_id': 'MLA1055',
#    'domain_id': 'MLA-CELLPHONES',
#    'variation_id': '185416028433',
#    'thumbnail': 'http://http2.mlstatic.com/D_989376-MLA79913908993_102024-O.jpg',
#    'currency_id': 'ARS',
#    'order_backend': 50,
#    'price': 1600000,
#    'original_price': None,
#    'sale_price': {'price_id': '',
#     'amount': 1600000,
#     'conditions': {'eligible': True,
#      'context_restrictions': [],
#      'start_time': None,
#      'end_time': None},
#     'currency_id': 'ARS',
#     'exchange_rate': None,
#     'payment_method_prices': [],
#     'payment_method_type': 'TMP',
#     'regular_amount': None,
#     'type': 'standard',
#     'metadata': {}},
#    'available_quantity': 1,
#    'official_store_id': None,
#    'use_thumbnail_id': False,
#    'accepts_mercadopago': True,
#    'variation_filters': ['COLOR'],
#    'shipping': {'store_pick_up': False,
#     'free_shipping': False,
#     'logistic_type': 'drop_off',
#     'mode': 'me2',
#     'tags': [],
#     'benefits': None,
#     'promise': None,
#     'shipping_score': -1},
#    'stop_time': '2044-10-06T04:00:00.000Z',
#    'seller': {'id': 543834473, 'nickname': 'LEGIONR1295'},
#    'attributes': [{'id': 'BRAND',
#      'name': 'Marca',
#      'value_id': '9344',
#      'value_name': 'Apple',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '9344',
#        'name': 'Apple',
#        'struct': None,
#        'source': 6288553339613210}],
#      'source': 6288553339613210,
#      'value_type': 'string'},
#     {'id': 'ITEM_CONDITION',
#      'name': 'Condición del ítem',
#      'value_id': '2230581',
#      'value_name': 'Usado',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '2230581',
#        'name': 'Usado',
#        'struct': None,
#        'source': 6288553339613210}],
#      'source': 6288553339613210,
#      'value_type': 'list'},
#     {'id': 'LINE',
#      'name': 'Línea',
#      'value_id': '13876686',
#      'value_name': 'iPhone 14',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '13876686',
#        'name': 'iPhone 14',
#        'struct': None,
#        'source': 6288553339613210}],
#      'source': 6288553339613210,
#      'value_type': 'string'},
#     {'id': 'MODEL',
#      'name': 'Modelo',
#      'value_id': '13188535',
#      'value_name': 'iPhone 14 Pro Max',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '13188535',
#        'name': 'iPhone 14 Pro Max',
#        'struct': None,
#        'source': 6288553339613210}],
#      'source': 6288553339613210,
#      'value_type': 'string'},
#     {'id': 'PROCESSOR_MODEL',
#      'name': 'Modelo del procesador',
#      'value_id': '13188555',
#      'value_name': 'Apple A16 Bionic',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': None,
#      'values': [{'id': '13188555',
#        'name': 'Apple A16 Bionic',
#        'struct': None,
#        'source': 6288553339613210}],
#      'source': 6288553339613210,
#      'value_type': 'string'},
#     {'id': 'WEIGHT',
#      'name': 'Peso',
#      'value_id': None,
#      'value_name': '240 g',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Otros',
#      'value_struct': {'number': 240, 'unit': 'g'},
#      'values': [{'id': None,
#        'name': '240 g',
#        'struct': {'unit': 'g', 'number': 240},
#        'source': 6288553339613210}],
#      'source': 6288553339613210,
#      'value_type': 'number_unit'}],
#    'variations_data': {'185416028433': {'thumbnail': 'http://http2.mlstatic.com/D_989376-MLA79913908993_102024-O.jpg',
#      'ratio': '1.02',
#      'name': 'Gris oscuro',
#      'pictures_qty': 2,
#      'price': 1600000,
#      'user_product_id': 'MLAU2218385560',
#      'attributes': [{'id': 'MAIN_COLOR',
#        'name': 'Color principal',
#        'value_name': 'list',
#        'value_type': 'Negro'}],
#      'attribute_combinations': None}},
#    'installments': {'quantity': 9,
#     'amount': 177777.78,
#     'rate': 0,
#     'currency_id': 'ARS',
#     'metadata': {'meliplus_installments': False,
#      'additional_bank_interest': False}},
#    'winner_item_id': None,
#    'catalog_listing': False,
#    'discounts': None,
#    'promotions': [],
#    'inventory_id': None}],
#  'sort': {'id': 'relevance', 'name': 'Más relevantes'},
#  'available_sorts': [{'id': 'price_asc', 'name': 'Menor precio'},
#   {'id': 'price_desc', 'name': 'Mayor precio'}],
#  'filters': [{'id': 'category',
#    'name': 'Categorías',
#    'type': 'text',
#    'values': [{'id': 'MLA1055',
#      'name': 'Celulares y Smartphones',
#      'path_from_root': [{'id': 'MLA1051', 'name': 'Celulares y Teléfonos'},
#       {'id': 'MLA1055', 'name': 'Celulares y Smartphones'}]}]},
#   {'id': 'BRAND',
#    'name': 'Marca',
#    'type': 'STRING',
#    'values': [{'id': '9344', 'name': 'Apple'}]}],
#  'available_filters': [{'id': 'state',
#    'name': 'Ubicación',
#    'type': 'text',
#    'values': [{'id': 'TUxBUENBUGw3M2E1',
#      'name': 'Capital Federal',
#      'results': 78},
#     {'id': 'TUxBUFNBTmU5Nzk2', 'name': 'Santa Fe', 'results': 29},
#     {'id': 'TUxBUEdSQWVmNTVm', 'name': 'Bs.As. G.B.A. Oeste', 'results': 22},
#     {'id': 'TUxBUEdSQWU4ZDkz', 'name': 'Bs.As. G.B.A. Norte', 'results': 21},
#     {'id': 'TUxBUEdSQXJlMDNm', 'name': 'Bs.As. G.B.A. Sur', 'results': 20},
#     {'id': 'TUxBUENPU2ExMmFkMw',
#      'name': 'Bs.As. Costa Atlántica',
#      'results': 5},
#     {'id': 'TUxBUFpPTmFpbnRl', 'name': 'Buenos Aires Interior', 'results': 5},
#     {'id': 'TUxBUE1FTmE5OWQ4', 'name': 'Mendoza', 'results': 2},
#     {'id': 'TUxBUE1JU3MzNjIx', 'name': 'Misiones', 'results': 2},
#     {'id': 'TUxBUENIVXQxNDM1MQ', 'name': 'Chubut', 'results': 2},
#     {'id': 'TUxBUEpVSnk3YmUz', 'name': 'Jujuy', 'results': 2},
#     {'id': 'TUxBUENPUmFkZGIw', 'name': 'Córdoba', 'results': 1},
#     {'id': 'TUxBUEZPUmE1OTk5', 'name': 'Formosa', 'results': 1},
#     {'id': 'TUxBUFLNT29iZmZm', 'name': 'Río Negro', 'results': 1}]},
#   {'id': 'price',
#    'name': 'Precio',
#    'type': 'range',
#    'values': [{'id': '*-1000000.0', 'name': 'Hasta $ 1.000.000', 'results': 5},
#     {'id': '1000000.0-1500000.0',
#      'name': '$1.000.000 a $1.500.000',
#      'results': 63},
#     {'id': '1500000.0-*', 'name': 'Más de $1.500.000', 'results': 131}]},
#   {'id': 'accepts_mercadopago',
#    'name': 'Filtro por MercadoPago',
#    'type': 'boolean',
#    'values': [{'id': 'yes', 'name': 'Con MercadoPago', 'results': 199}]},
#   {'id': 'installments',
#    'name': 'Financiación',
#    'type': 'text',
#    'values': [{'id': 'yes', 'name': 'En cuotas', 'results': 1},
#     {'id': 'no_interest', 'name': 'Sin interés', 'results': 19}]},
#   {'id': 'shipping',
#    'name': 'Envío',
#    'type': 'text',
#    'values': [{'id': 'mercadoenvios',
#      'name': 'Mercado Envíos',
#      'results': 197}]},
#   {'id': 'power_seller',
#    'name': 'Filtro por calidad de vendedores',
#    'type': 'boolean',
#    'values': [{'id': 'yes', 'name': 'Mejores vendedores', 'results': 46}]},
#   {'id': 'since',
#    'name': 'Filtro por fecha de comienzo',
#    'type': 'text',
#    'values': [{'id': 'today', 'name': 'Publicados hoy', 'results': 8}]},
#   {'id': 'has_video',
#    'name': 'Filtro por publicaciones con video',
#    'type': 'boolean',
#    'values': [{'id': 'yes', 'name': 'Publicaciones con video', 'results': 1}]},
#   {'id': 'has_pictures',
#    'name': 'Filtro por publicaciones con imágenes',
#    'type': 'boolean',
#    'values': [{'id': 'yes', 'name': 'Con fotos', 'results': 199}]},
#   {'id': 'shipping_cost',
#    'name': 'Costo de envío',
#    'type': 'text',
#    'values': [{'id': 'free', 'name': 'Gratis', 'results': 69}]},
#   {'id': 'CARRIER',
#    'name': 'Compañía telefónica',
#    'type': 'STRING',
#    'values': [{'id': '298335', 'name': 'Liberado', 'results': 195},
#     {'id': '298333', 'name': 'Claro', 'results': 2},
#     {'id': '303171', 'name': 'Personal', 'results': 1},
#     {'id': '303170', 'name': 'Movistar', 'results': 1}]},
#   {'id': 'INTERNAL_MEMORY',
#    'name': 'Memoria interna',
#    'type': 'range',
#    'values': [{'id': '(*-256GB)', 'name': 'Menos de 256 GB', 'results': 85},
#     {'id': '[256GB-512GB)', 'name': '256 a 511 GB', 'results': 72},
#     {'id': '[512GB-1TB)', 'name': '512 a 1 TB', 'results': 33},
#     {'id': '[1TB-*)', 'name': '1 TB o más', 'results': 9}]},
#   {'id': 'IS_DUAL_SIM',
#    'name': 'Otras características',
#    'type': 'boolean',
#    'values': [{'id': '242085', 'name': 'Es Dual SIM', 'results': 17}]},
#   {'id': 'IS_DUST_RESISTANT',
#    'name': 'Otras características',
#    'type': 'boolean',
#    'values': [{'id': '242085',
#      'name': 'Es resistente al polvo',
#      'results': 169}]},
#   {'id': 'IS_WATER_RESISTANT',
#    'name': 'Otras características',
#    'type': 'boolean',
#    'values': [{'id': '242085',
#      'name': 'Es resistente al agua',
#      'results': 169}]},
#   {'id': 'ITEM_CONDITION',
#    'name': 'Condición',
#    'type': 'STRING',
#    'values': [{'id': '2230581', 'name': 'Usado', 'results': 184},
#     {'id': '2230284', 'name': 'Nuevo', 'results': 13},
#     {'id': '2230582', 'name': 'Reacondicionado', 'results': 2}]},
#   {'id': 'LINE',
#    'name': 'Línea',
#    'type': 'STRING',
#    'values': [{'id': '13876686', 'name': 'iPhone 14', 'results': 187},
#     {'id': '58993', 'name': 'iPhone', 'results': 3}]},
#   {'id': 'MAIN_COLOR',
#    'name': 'Color principal',
#    'type': 'list',
#    'values': [{'id': '2450295', 'name': 'Negro', 'results': 76},
#     {'id': '2450311', 'name': 'Violeta', 'results': 39},
#     {'id': '2450289', 'name': 'Dorado', 'results': 28},
#     {'id': '2450303', 'name': 'Plateado', 'results': 23},
#     {'id': '2450290', 'name': 'Violeta oscuro', 'results': 4},
#     {'id': '2450308', 'name': 'Blanco', 'results': 1},
#     {'id': '2450293', 'name': 'Azul', 'results': 1}]},
#   {'id': 'MAIN_REAR_CAMERA_RESOLUTION',
#    'name': 'Resolución de la cámara trasera principal',
#    'type': 'range',
#    'values': [{'id': '(*-48Mpx)', 'name': '48 Mpx o menos', 'results': 168},
#     {'id': '[48Mpx-*)', 'name': '48 Mpx o más', 'results': 1}]},
#   {'id': 'MOBILE_NETWORK',
#    'name': 'Red móvil',
#    'type': 'STRING',
#    'values': [{'id': '7472027', 'name': '5G', 'results': 175},
#     {'id': '367876', 'name': '4G/LTE', 'results': 3},
#     {'id': '9133368', 'name': '4G', 'results': 1}]},
#   {'id': 'MODEL',
#    'name': 'Modelo',
#    'type': 'STRING',
#    'values': [{'id': '13188535',
#      'name': 'iPhone 14 Pro Max',
#      'results': 187}]},
#   {'id': 'OPERATING_SYSTEM_NAME',
#    'name': 'Nombre del sistema operativo',
#    'type': 'STRING',
#    'values': [{'id': '7404961', 'name': 'iOS', 'results': 186}]},
#   {'id': 'RAM',
#    'name': 'Memoria RAM',
#    'type': 'range',
#    'values': [{'id': '(*-8GB)', 'name': 'Menos de 8 GB', 'results': 181},
#     {'id': '[8GB-128GB)', 'name': '8 a 127 GB', 'results': 10},
#     {'id': '[128GB-*)', 'name': '128 GB o más', 'results': 8}]},
#   {'id': 'WITH_ACCELEROMETER',
#    'name': 'Otras características',
#    'type': 'boolean',
#    'values': [{'id': '242085', 'name': 'Con acelerómetro', 'results': 166}]},
#   {'id': 'WITH_BAROMETER',
#    'name': 'Otras características',
#    'type': 'boolean',
#    'values': [{'id': '242085', 'name': 'Con barómetro', 'results': 166}]},
#   {'id': 'WITH_BLUETOOTH',
#    'name': 'Otras características',
#    'type': 'boolean',
#    'values': [{'id': '242085', 'name': 'Con Bluetooth', 'results': 169}]},
#   {'id': 'WITH_CAMERA',
#    'name': 'Otras características',
#    'type': 'boolean',
#    'values': [{'id': '242085', 'name': 'Con cámara', 'results': 169}]},
#   {'id': 'WITH_COMPASS',
#    'name': 'Otras características',
#    'type': 'boolean',
#    'values': [{'id': '242085', 'name': 'Con brújula', 'results': 169}]},
#   {'id': 'WITH_ESIM',
#    'name': 'Otras características',
#    'type': 'boolean',
#    'values': [{'id': '242085', 'name': 'Con eSIM', 'results': 165}]},
#   {'id': 'WITH_FACIAL_RECOGNITION',
#    'name': 'Otras características',
#    'type': 'boolean',
#    'values': [{'id': '242085',
#      'name': 'Con reconocimiento facial',
#      'results': 169}]},
#   {'id': 'WITH_FAST_CHARGING',
#    'name': 'Otras características',
#    'type': 'boolean',
#    'values': [{'id': '242085', 'name': 'Con carga rápida', 'results': 168}]},
#   {'id': 'WITH_FINGERPRINT_READER',
#    'name': 'Otras características',
#    'type': 'boolean',
#    'values': [{'id': '242085',
#      'name': 'Con lector de huella digital',
#      'results': 1}]},
#   {'id': 'WITH_FRONT_CAMERA_FLASH',
#    'name': 'Otras características',
#    'type': 'boolean',
#    'values': [{'id': '242085',
#      'name': 'Con flash en la cámara frontal',
#      'results': 164}]},
#   {'id': 'WITH_GPS',
#    'name': 'Otras características',
#    'type': 'boolean',
#    'values': [{'id': '242085', 'name': 'Con GPS', 'results': 169}]},
#   {'id': 'WITH_GYROSCOPE',
#    'name': 'Otras características',
#    'type': 'boolean',
#    'values': [{'id': '242085', 'name': 'Con giroscopio', 'results': 169}]},
#   {'id': 'WITH_NFC',
#    'name': 'Otras características',
#    'type': 'boolean',
#    'values': [{'id': '242085', 'name': 'Con NFC', 'results': 169}]},
#   {'id': 'WITH_PROXIMITY_SENSOR',
#    'name': 'Otras características',
#    'type': 'boolean',
#    'values': [{'id': '242085',
#      'name': 'Con sensor de proximidad',
#      'results': 169}]},
#   {'id': 'WITH_SOS_BUTTON',
#    'name': 'Otras características',
#    'type': 'boolean',
#    'values': [{'id': '242085', 'name': 'Con botón SOS', 'results': 164}]},
#   {'id': 'WITH_TOUCHSCREEN_DISPLAY',
#    'name': 'Otras características',
#    'type': 'boolean',
#    'values': [{'id': '242085',
#      'name': 'Con pantalla táctil',
#      'results': 169}]},
#   {'id': 'WITH_WIFI',
#    'name': 'Wi-Fi',
#    'type': 'boolean',
#    'values': [{'id': '242085', 'name': 'Con Wi-Fi', 'results': 169}]},
#   {'id': 'WITH_WIRELESS_CHARGING',
#    'name': 'Otras características',
#    'type': 'boolean',
#    'values': [{'id': '242085',
#      'name': 'Con carga inalámbrica',
#      'results': 169}]}],
#  'pdp_tracking': {'group': False, 'product_info': []},
#  'user_context': None}

# %%
#Ejercicio 2

#Cantidad de Resultados que obtenemos
print('Longitud de lista de resultados:', len(data['results']))

# Veamos el precio del primer resultado de la búsqueda
print('Precio del primer resultado:', data['results'][0]['price'])


import pandas as pd

precios = []

# Extraemos los valores de 'id' y 'price' 
for i, resultado in enumerate(data['results']): 
    if 'id' in resultado and 'price' in resultado:
        precios.append([resultado['id'], resultado['price']])  # Añadir el par [id, price]
    else:
        print(f"Faltan datos en el resultado {i}: {resultado}")

# Convertimos la lista de listas en un DataFrame
df_precios = pd.DataFrame(precios, columns=['id', 'Precio'])

# Mostramos el DataFrame
print(df_precios)


#precio promedio:
print('Precio promedio:', df_precios['Precio'].mean())   #1834099.74

#precio máximo:
print('Precio máximo:',df_precios['Precio'].max())    #5999999

#precio minimo:
print('Precio minimo:',df_precios['Precio'].min())    #145000
# Out:
# Longitud de lista de resultados: 50
# Precio del primer resultado: 1720000
#                id   Precio
# 0   MLA1890488344  1720000
# 1   MLA1890309638  1720000
# 2   MLA1452977585  1950000
# 3   MLA1414395007  3000000
# 4   MLA1870249594  2320000
# 5   MLA1889892184  1890000
# 6   MLA1853088714  1891000
# 7   MLA1889993976  1890000
# 8   MLA1385783071  3399999
# 9   MLA1490056284  3399999
# 10  MLA1489753500  5999999
# 11  MLA1454403375  1250000
# 12  MLA1451049867  1690000
# 13  MLA1391815411  1899999
# 14  MLA1453761721  1400000
# 15  MLA1438219007  1800000
# 16  MLA1454327547  1400000
# 17  MLA1441965381  1915200
# 18  MLA1454833449  1650000
# 19  MLA1442196997  1915200
# 20  MLA1441885423  1971200
# 21  MLA1453932713  1429991
# 22  MLA1441888135  1915200
# 23  MLA1933057928  1728600
# 24  MLA1441924365  1971200
# 25  MLA1442222187  1915200
# 26  MLA1878327128  1825600
# 27  MLA1441963743  1948800
# 28  MLA1875959588  1915200
# 29  MLA1878339542  1825600
# 30  MLA1441964143  1948800
# 31  MLA1441888491  1915200
# 32  MLA1454900447  1799000
# 33  MLA1454981385  1300000
# 34  MLA1934020440  1350000
# 35  MLA1454287409   145000
# 36  MLA1928755486  1300000
# 37  MLA1808025690  1500000
# 38  MLA1454441025  1500000
# 39  MLA1928209894  1400000
# 40  MLA1924957400   480000
# 41  MLA1933999294  2100000
# 42  MLA1454942791  1550000
# 43  MLA1933948650  1170000
# 44  MLA1931374654  1900000
# 45  MLA1452240937  1750000
# 46  MLA1919880910  1649000
# 47  MLA1454961445  1300000
# 48  MLA1443289293  1500000
# 49  MLA1454867903  1600000
# Precio promedio: 1834099.74
# Precio máximo: 5999999
# Precio minimo: 145000

# %%
#Ejercicio 3

import matplotlib.pyplot as plt
import numpy as np

#para poder visualizarlo 
# %matplotlib inline

plt.hist(df_precios['Precio'], bins=40, edgecolor='black')  
plt.title('Histograma de Precios')
plt.xlabel('Precio')        # muestra los precios multiplicados por 1 millón
plt.ylabel('Frecuencia')
plt.show()

#A simple vista hay 6 outliers; 2 items muy baratos y 4 items demasiado caros. El precio de la mayoria de los items ronda entre 1 y 2 millones de pesos.

# %%
#Ejercicio 4

# %% [markdown]
# ## Parte B

# %% [markdown]
# ### Ejercicio 5
# De la página de noticias del diario La Nación, utilicen herramientas de web scraping para obtener los links de las noticias de la portada. Guarden los links obtenidos en un dataframe y expórtenlo a un archivo de excel.

# %%
# Instalamos las librerías necesarias
# !pip install requests 
# !pip install BeautifulSoup 
# !pip install pandas
# Out:
# Requirement already satisfied: requests in /opt/anaconda3/lib/python3.12/site-packages (2.32.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.12/site-packages (from requests) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.12/site-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.12/site-packages (from requests) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.12/site-packages (from requests) (2024.8.30)
# Collecting BeautifulSoup
#   Using cached BeautifulSoup-3.2.2.tar.gz (32 kB)
#   Preparing metadata (setup.py) ... error
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> [7 lines of output]
#       Traceback (most recent call last):
#         File "<string>", line 2, in <module>
#         File "<pip-setuptools-caller>", line 34, in <module>
#         File "/private/var/folders/jc/yy257_d12sx_8p7gmysn10dr0000gn/T/pip-install-sj461aqc/beautifulsoup_1504d499879d494395081def73cb3888/setup.py", line 3
#           "You're trying to run a very old release of Beautiful Soup under Python 3. This will not work."<>"Please use Beautiful Soup 4, available through the pip package 'beautifulsoup4'."
#                                                                                                          ^^
#       SyntaxError: invalid syntax
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.
# Requirement already satisfied: pandas in /opt/anaconda3/lib/python3.12/site-packages (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in /opt/anaconda3/lib/python3.12/site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.12/site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/lib/python3.12/site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
# Importamos las librerías
import requests #html requestor
from bs4 import BeautifulSoup #html parser
import pandas as pd #dataframe manipulator

# %%
# Guardo el URL de la página del diario de La Nación
url = "https://www.lanacion.com.ar/"

# %%
# Traigo el contenido del URL a mi dispositivo
r = requests.get(url) #traigo el contenido del html
contenido = r.content

# %%
# Procesamos el contenido obtenido del URL para poder trabajar con el código HTML
soup = BeautifulSoup(contenido, "html.parser")
soup
# Out:
# <!DOCTYPE html>
# <html lang="es"><head><meta charset="utf-8"/><meta content="width=device-width,initial-scale=1.0,minimum-scale=0.5,maximum-scale=5.0,user-scalable=yes" name="viewport"/><meta content="#ffffff" name="theme-color"/><title>Últimas noticias de Argentina y el mundo - LA NACION</title><link as="image" fetchpriority="high" href="https://www.lanacion.com.ar/resizer/v2/javier-milei-y-luiz-inacio-lula-da-UNLVPBQOLFAELC7BYTG2CEUGCI.JPG?auth=6f3bf80b019a1d4f162b6febd630c38f9e1b0fd925caef1e96cf8282f5364607&amp;width=488&amp;height=325&amp;quality=70&amp;smart=true" media="(min-width: 768px)" rel="preload"/><link as="image" fetchpriority="high" href="https://www.lanacion.com.ar/resizer/v2/javier-milei-y-luiz-inacio-lula-da-UNLVPBQOLFAELC7BYTG2CEUGCI.JPG?auth=6f3bf80b019a1d4f162b6febd630c38f9e1b0fd925caef1e96cf8282f5364607&amp;width=420&amp;height=280&amp;quality=70&amp;smart=true" media="(max-width: 767px)" rel="preload"/><style id="critical-fonts">
# @font-face {font-family:'Prumo';src:url('/pf/resources/fonts/prumo/Prumo-LNVF.woff2?d=1690') format('woff2-variations'); font-weight: 90; font-display: swap;}
# @font-face {font-family:'Prumo Italic';src:url('/pf/resources/fonts/prumo/Prumo-ItalicLNVF.woff2?d=1690') format('woff2-variations'); font-weight: 90; font-display: swap;}
# </style><style id="critical-css">.button{display:inline-flex;align-items:center;justify-content:center;cursor:pointer;width:-moz-max-content;width:max-content;height:-moz-max-content;height:max-content;font-size:.75rem;line-height:1rem;text-transform:uppercase;white-space:nowrap}.button,.button>.icon>svg>path{transition:all .3s ease-in-out}.button:hover{opacity:.8}.button:disabled{opacity:.4;pointer-events:none}.dropdown .dropdown-menu:after{content:"";height:.5rem;width:1.5rem;display:inline-block;position:absolute;bottom:100%;background-image:url(data:image/svg+xml;base64,...);background-size:1.5rem .5rem}.dropdown .dropdown-menu:before{content:"";height:.5rem;position:absolute;left:0;bottom:100%;width:100%}.dropdown .dropdown-menu[data-position=left]{left:0}.dropdown .dropdown-menu[data-position=left]:after{left:.6875rem}.dropdown .dropdown-menu[data-position=center],.dropdown .dropdown-menu[data-position=center]::after{left:50%;transform:translate3d(-50%,0,0)}.dropdown .dropdown-menu[data-position=right]{right:0}.dropdown .dropdown-menu[data-position=right]::after{right:.6875rem}.dropdown .icon.dropdown-icon{transition-property:transform}.dropdown .icon.dropdown-icon.--rotate{transform:rotate(180deg)}.--grid-jc-start{justify-content:start}.--grid-jc-end{justify-content:end}.--grid-jc-center{justify-content:center}.--grid-jc-stretch{justify-content:stretch}.--grid-jc-around{justify-content:space-around}.--grid-jc-between{justify-content:space-between}.--grid-jc-evenly{justify-content:space-evenly}.--grid-as-start{align-self:start}.--grid-as-end{align-self:end}.--grid-as-center{align-self:center}.--grid-as-stretch{align-self:stretch}.--grid-as-around{align-self:space-around}.--grid-as-between{align-self:space-between}.--grid-as-evenly{align-self:space-evenly}.--grid-ai-start{align-items:start}.--grid-ai-end{align-items:end}.--grid-ai-center{align-items:center}.--grid-ai-stretch{align-items:stretch}.grid{position:relative;display:grid;width:100%;min-width:-moz-min-content;min-width:min-content}.grid.--gap-none{grid-row-gap:none}.grid.--gap-2xs{grid-row-gap:.25rem}.grid.--gap-xs{grid-row-gap:.5rem}.grid.--gap-sm{grid-row-gap:1rem}.grid.--gap-md{grid-row-gap:1.5rem}.grid.--gap-lg{grid-row-gap:2rem}.grid.--gap-xl{grid-row-gap:2.5rem}.grid.--gap-2xl{grid-row-gap:4rem}.grid.--gap-3xl{grid-row-gap:5rem}.grid.--grid-cols-1{grid-template-columns:repeat(1,1fr);grid-column-gap:16px}.grid.--grid-cols-2{grid-template-columns:repeat(2,1fr);grid-column-gap:16px}.grid.--grid-cols-3{grid-template-columns:repeat(3,1fr);grid-column-gap:16px}.grid.--grid-cols-4{grid-template-columns:repeat(4,1fr);grid-column-gap:16px}.grid.--grid-cols-5{grid-template-columns:repeat(5,1fr);grid-column-gap:16px}.grid.--grid-cols-6{grid-template-columns:repeat(6,1fr);grid-column-gap:16px}.grid.--grid-cols-7{grid-template-columns:repeat(7,1fr);grid-column-gap:16px}.grid.--grid-cols-8{grid-template-columns:repeat(8,1fr);grid-column-gap:16px}@media(min-width:48rem){.grid.--grid-cols-md-1{grid-template-columns:repeat(1,1fr);grid-column-gap:24px}.grid.--grid-cols-md-2{grid-template-columns:repeat(2,1fr);grid-column-gap:24px}.grid.--grid-cols-md-3{grid-template-columns:repeat(3,1fr);grid-column-gap:24px}.grid.--grid-cols-md-4{grid-template-columns:repeat(4,1fr);grid-column-gap:24px}.grid.--grid-cols-md-5{grid-template-columns:repeat(5,1fr);grid-column-gap:24px}.grid.--grid-cols-md-6{grid-template-columns:repeat(6,1fr);grid-column-gap:24px}.grid.--grid-cols-md-7{grid-template-columns:repeat(7,1fr);grid-column-gap:24px}.grid.--grid-cols-md-8{grid-template-columns:repeat(8,1fr);grid-column-gap:24px}.grid.--grid-cols-md-9{grid-template-columns:repeat(9,1fr);grid-column-gap:24px}.grid.--grid-cols-md-10{grid-template-columns:repeat(10,1fr);grid-column-gap:24px}.grid.--grid-cols-md-11{grid-template-columns:repeat(11,1fr);grid-column-gap:24px}.grid.--grid-cols-md-12{grid-template-columns:repeat(12,1fr);grid-column-gap:24px}}@media(min-width:64rem){.grid.--grid-cols-lg-1{grid-te ...
# </style><script id="polyfill-script" type="application/javascript">if(!Array.prototype.includes||!(window.Object && window.Object.assign)||!window.Promise||!window.Symbol||!window.fetch){document.write('<script type="application/javascript" src="/pf/dist/engine/polyfill.js?d=1690" defer=""><\/script>')}</script><script defer="" id="fusion-engine-react-script" src="/pf/dist/engine/react.js?d=1690" type="application/javascript"></script><script defer="" id="fusion-engine-combinations-script" src="/pf/dist/components/combinations/default.js?d=1690" type="application/javascript"></script><link href="https://www.googletagmanager.com" rel="dns-prefetch"/><link href="https://www.googletagmanager.com" rel="preconnect"/><link href="https://www.google-analytics.com" rel="preconnect"/><link href="https://www.google-analytics.com" rel="dns-prefetch"/><link href="https://sb.scorecardresearch.com" rel="preconnect"/><link href="https://sb.scorecardresearch.com" rel="dns-prefetch"/><link href="https://securepubads.g.doubleclick.net" rel="preconnect"/><link href="https://securepubads.g.doubleclick.net" rel="dns-prefetch"/><link href="https://c.amazon-adsystem.com" rel="preconnect"/><link href="https://c.amazon-adsystem.com" rel="dns-prefetch"/><link href="https://www.googletagservices.com" rel="preconnect"/><link href="https://www.googletagservices.com" rel="dns-prefetch"/><link href="https://s.go-mpulse.net" rel="preconnect"/><link href="https://s.go-mpulse.net" rel="dns-prefetch"/><link crossorigin="" href="https://c.go-mpulse.net" rel="preconnect"/><link crossorigin="" href="https://c.go-mpulse.net" rel="dns-prefetch"/><link href="https://events.newsroom.bi" rel="dns-prefetch"/><link href="https://events.newsroom.bi" rel="preconnect"/><script async="" id="scriptDataLayerHome" src="/pf/resources/js/LN/scriptDataLayerHome.min.js?d=1690" type="text/javascript"></script><script async="" type="text/javascript">
#     const getMyCookie = function getCookie(nameCookie) {
#     if (!nameCookie) return undefined;
#     const value = `; ${typeof document !== 'undefined' ? document.cookie : ''}`;
#     const parts = value.split(`; ${nameCookie}=`);
#     return parts.length === 2 ? parts.pop().split(';').shift() : undefined;
#   };
#
#     const gaIdCookie = getMyCookie('_ga');
#     const googleAnalyticsId =  gaIdCookie && gaIdCookie.split('.').splice(2,2).join('.');
#     const usuarioEmail = getMyCookie('usuarioemail');
#
#     (function (h, o, u, n, d) {
#         h = h[d] = h[d] || {
#           q: [],
#           onReady: function (c) {
#             h.q.push(c);
#           },
#         };
#         d = o.createElement(u);
#         d.async = 1;
#         d.src = n;
#         n = o.getElementsByTagName(u)[0];
#         n.parentNode.insertBefore(d, n);
#       })(
#         window,
#         document,
#         "script",
#         "https://www.datadoghq-browser-agent.com/datadog-logs-v5.js",
#         "DD_LOGS"
#       );
#       DD_LOGS.onReady(function () {
#         DD_LOGS.init({
#           clientToken: "pubaa01cb67f0a687a6eba4718413593f4f",
#           site: "datadoghq.com",
#           forwardErrorsToLogs: true,
#           sessionSampleRate: 1,
#           service: "lanacion-arc",
#           env: "prod",
#           version: "1690",
#           trackSessionAcrossSubdomains: false,
#         });
#
#         googleAnalyticsId && DD_LOGS.logger.setContextProperty('user.gaId', googleAnalyticsId);
#         usuarioEmail && DD_LOGS.logger.setContextProperty('user.email', usuarioEmail);
#
#         if ("prod" !== "prod")
#           console.log(
#             `Datadog initialized. Version: 1690, sampleRate: 1, env: prod`
#           );
#       });
#     </script><script async="" type="text/javascript">
#     (function (h, o, u, n, d) {
#         h = h[d] = h[d] || {
#           q: [],
#           onReady: function (c) {
#             h.q.push(c);
#           },
#         };
#         d = o.createElement(u);
#         d.async = 1;
#         d.src = n;
#         n = o.getElementsByTagName(u)[0];
#         n.parentNode.insertBefore(d, n);
#       })(
#         window,
#         document,
#         "script",
#         "https://www.datadoghq-browser-agent.com/datadog-rum-v5.js",
#         "DD_RUM"
#       );
#
#       DD_RUM.onReady(function () {
#         DD_RUM.init({
#           clientToken: "pubaa01cb67f0a687a6eba4718413593f4f",
#           applicationId: "bcea4545-f033-4b09-ab27-30995db5acb0",
#           site: "datadoghq.com",
#           service: "lanacion-arc",
#           env: "prod",
#           version: "1690",
#           sessionSampleRate: 0.15,
#           sessionReplaySampleRate: 41,
#           trackResources: true,
#           trackLongTasks: true,
#           trackUserInteractions: true,
#           trackSessionAcrossSubdomains: false,
#           defaultPrivacyLevel: "mask-user-input",
#         });
#
#         DD_RUM.startSessionReplayRecording();
#
#         if (googleAnalyticsId || usuarioEmail) {
#           DD_RUM.setUser({
#             ...(googleAnalyticsId && { gaId: googleAnalyticsId }),
#             ...(usuarioEmail && { email: usuarioEmail })
#           });
#         }
#
#         if ("prod" !== "prod")
#             console.log(
#               `Datadog RUM initialized. Version: 1690, sampleRate: 0.15, env: prod`
#             );
#       });</script><script async="" data-obj='{"layout":"LN10-Home_Main","outputType":"default","template":"page/pWucuzZgevMwF3ys"}' defer="" id="script-configure-datadog-context" src="/pf/resources/js/LN/configureDatadogContext.min.js?d=1690" type="text/javascript"></script><script async="" data-article="{}" data-get-cookie="function getCookie(nameCookie) {
#     if (!nameCookie) return undefined;
#     const value = `; ${typeof document !== 'undefined' ? document.cookie : ''}`;
#     const parts = value.split(`; ${nameCookie}=`);
#     return parts.length === 2 ? parts.pop().split(';').shift() : undefined;
#   }" data-layout="LN10-Home_Main" id="script-permutive" src="/pf/resources/js/LN/Permutive.min.js?d=1690" type="text/javascript"></script><script async="" src="https://867f8423-d142-4fd1-ae8d-1a9bbbdf2358.edge.permutive.app/867f8423-d142-4fd1-ae8d-1a9bbbdf2358-web.js"></script><script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#     new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#     j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#     'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#     })(window,document,'script','dataLayer','GTM-GHV6');</script><script defer="" id="comscore" type="text/javascript">var _comscore = _comscore || [];
#         _comscore.push({"c1":"2","c2":"6906398","options":{"enableFirstPartyCookie":true,"bypassUserConsentRequirementFor1PCookie":true}});(function() {
#             var s = document.createElement("script"), el = document.getElementsByTagName("script")[0]; s.async = true;
#             s.src = "https://sb.scorecardresearch.com/cs/6906398/beacon.js";
#             el.parentNode.insertBefore(s, el);
#             })();</script><noscript><img src="https://sb.scorecardresearch.com/p?c1=2&amp;c2=6906398&amp;cv=3.9.1&amp;cj=1"/></noscript><script async="" src=" https://securepubads.g.doubleclick.net/tag/js/gpt.js?network-code=133919216"></script><script async="" data-create-hash="data =&gt; {
#   const encoder = new TextEncoder();
#   const dataBuffer = encoder.encode(data);
#   return crypto.subtle ? crypto.subtle.digest('SHA-256', dataBuffer).then(hashBuffer =&gt; {
#     if (hashBuffer) {
#       const hashArray = Array.from(new Uint8Array(hashBuffer));
#       return hashArray.map(byte =&gt; byte.toString(16).padStart(2, '0')).join('');
#     }
#   }) : Promise.reject('crypto.subtle only works on HTTPS');
# }" data-get-cookie="function getCookie(nameCookie) {
#     if (!nameCookie) return undefined;
#     const value = `; ${typeof document !== 'undefined' ? document.cookie : ''}`;
#     const parts = value.split(`; ${nameCookie}=`);
#     return parts.length === 2 ? parts.pop().split(';').shift() : undefined;
#   }" data-new-tags="[]" id="googlePublisherTag-metadata" src="/pf/resources/js/LN/googlePublisherTagAcumulado.min.js?d=1690" type="text/javascript"></script><script async="" id="scriptAmazonPublisherServices" src="/pf/resources/js/LN/scriptAmazonPublisherServices.min.js?d=1690" type="text/javascript"></script><script type="text/javascript">!function(){"use strict";function e(e){var t=!(arguments.length>1&&void 0!==arguments[1])||arguments[1],c=document.createElement("script");c.src=e,t?c.type="module":(c.async=!0,c.type="text/javascript",c.setAttribute("nomodule",""));var n=document.getElementsByTagName("script")[0];n.parentNode.insertBefore(c,n)}!function(t,c){!function(t,c,n){var a,o,r;n.accountId=c,null!==(a=t.marfeel)&&void 0!==a||(t.marfeel={}),null!==(o=(r=t.marfeel).cmd)&&void 0!==o||(r.cmd=[]),t.marfeel.config=n;var i="https://sdk.mrf.io/statics";e("".concat(i,"/marfeel-sdk.js?id=").concat(c),!0),e("".concat(i,"/marfeel-sdk.es5.js?id=").concat(c),!1)}(t,c,arguments.length>2&&void 0!==arguments[2]?arguments[2]:{})}(window,3353 /* AccountId */,{} /* Config */)}();</script><script defer="" src="/pf/resources/js/common/eventsHelper.min.js?d=1690" type="application/javascript"></script><script async="" defer="" env="prod" id="oneTag" src="https://get.s-onetag.com/9d71fbce-de9f-46c1-b098-88de3c10d405/tag.min.js" type="text/javascript"></script><meta content="154042854349421" property="fb:app_id"/><meta content="website" property="og:type"/><meta content="Últimas noticias de Argentina y el mundo" property="og:title"/><meta content="LA NACION ofrece las últimas noticias, fotos y videos de la Argentina y el mundo. Política, economía, deportes y toda la información en tiempo real." property="og:description"/><meta content="https://arc-static.glanacion.com/pf/resources/images/placeholderLN-1200x630.png?d=1690" property="og:image"/><meta content="1200" property="og:image:width"/><meta content="630" property="og:image:height"/><meta content="https://www.lanacion.com.ar/" property="og:url"/><meta content="LA NACION" property="og:site_name"/><meta content="https://arc-static.glanacion.com/pf/resources/images/placeholderLN-1200x630.png?d=1690" name="twitter:image"/><link href="https://www.lanacion.com.ar/" rel="canonical"/><meta content="Últimas noticias de Argentina y el mundo - LA NACION" name="title"/><meta content="LA NACION ofrece las últimas noticias, fotos y videos de la Argentina y el mundo. Política, economía, deportes y toda la información en tiempo real." name="description"/><script type="application/ld+json">{
#         "@context": "http://schema.org",
#         "@type": "NewsMediaOrganization",
#         "name": "LA NACION",
#         "url": "https://www.lanacion.com.ar/",
#         "description": "Últimas noticias de Argentina y el mundo – LA NACION",
#         "alternateName": "LN",
#         "diversityPolicy": "https://www.lanacion.com.ar/sociedad/diversidad-redaccion-nid2413327/",
#         "ethicsPolicy": "https://www.lanacion.com.ar/sociedad/la-nacion-mision-estructura-empresarial-principios-eticos-nid2393569/",
#         "masthead": "https://www.lanacion.com.ar/sociedad/equipo-editorial-la-nacion-nid2390490/",
#         "publishingPrinciples": "https://www.lanacion.com.ar/sociedad/los-veinte-20-principios-del-periodismo-la-nid2390521/",
#         "verificationFactCheckingPolicy": "https://www.lanacion.com.ar/sociedad/verificacion-chequeo-datos-nid2406825/",
#         "foundingDate": "1870-01-04",
#         "logo": {
#             "@context": "https://schema.org",
#             "@type": "ImageObject",
#             "url": "https://arc-static.glanacion.com/pf/resources/images/placeholderLN-1280x1280.jpg?d=1690",
#             "height": 1280,
#             "width": 1280
#           },
#         "sameAs": [
#           "https://www.facebook.com/lanacion/",
#           "https://www.instagram.com/lanacioncom/",
#           "https://twitter.com/LANACION"
#         ]
#       }</script><script type="application/ld+json">{
#         "@context":"http://schema.org",
#         "@type":"WebSite",
#         "name": "LA NACION",
#         "url":"https://www.lanacion.com.ar/"
#     }</script><link href="/pf/resources/images/favicon.ico?d=1690" rel="shortcut icon" type="image/x-icon"/><link href="/pf/resources/images/favicon-16.png?d=1690" rel="icon" sizes="16x16" type="image/png"/><link href="/pf/resources/images/favicon-32.png?d=1690" rel="icon" sizes="32x32" type="image/png"/><link href="/pf/resources/images/favicon-192.png?d=1690" rel="shortcut icon" sizes="192x192" type="image/png"/><link href="/pf/resources/images/favicon-512.png?d=1690" rel="shortcut icon" sizes="512x512" type="image/png"/><link href="/pf/resources/images/favicon-192.png?d=1690" rel="apple-touch-icon"/><link href="/pf/resources/images/favicon-512.png?d=1690" rel="apple-touch-icon" sizes="512x512"/><link href="/manifest.json" rel="manifest"/>
# <script>(window.BOOMR_mq=window.BOOMR_mq||[]).push(["addVar",{"rua.upush":"false","rua.cpush":"false","rua.upre":"false","rua.cpre":"false","rua.uprl":"false","rua.cprl":"false","rua.cprf":"false","rua.trans":"","rua.cook":"false","rua.ims":"false","rua.ufprl":"false","rua.cfprl":"false","rua.isuxp":"false","rua.texp":"norulematch","rua.ceh":"false","rua.ueh":"false","rua.ieh.st":"0"}]);</script>
# <script>!function(e){var n="https://s.go-mpulse.net/boomerang/";if("False"=="True")e.BOOMR_config=e.BOOMR_config||{},e.BOOMR_config.PageParams=e.BOOMR_config.PageParams||{},e.BOOMR_config.PageParams.pci=!0,n="https://s2.go-mpulse.net/boomerang/";if(window.BOOMR_API_key="FPXUV-CWEKR-ELG8D-URM4T-QZGQK",function(){function e(){if(!o){var e=document.createElement("script");e.id="boomr-scr-as",e.src=window.BOOMR.url,e.async=!0,i.parentNode.appendChild(e),o=!0}}function t(e){o=!0;var n,t,a,r,d=document,O=window;if(window.BOOMR.snippetMethod=e?"if":"i",t=function(e,n){var t=d.createElement("script");t.id=n||"boomr-if-as",t.src=window.BOOMR.url,BOOMR_lstart=(new Date).getTime(),e=e||d.body,e.appendChild(t)},!window.addEventListener&&window.attachEvent&&navigator.userAgent.match(/MSIE [67]\./))return window.BOOMR.snippetMethod="s",void t(i.parentNode,"boomr-async");a=document.createElement("IFRAME"),a.src="about:blank",a.title="",a.role="presentation",a.loading="eager",r=(a.frameElement||a).style,r.width=0,r.height=0,r.border=0,r.display="none",i.parentNode.appendChild(a);try{O=a.contentWindow,d=O.document.open()}catch(_){n=document.domain,a.src="javascript:var d=document.open();d.domain='"+n+"';void(0);",O=a.contentWindow,d=O.document.open()}if(n)d._boomrl=function(){this.domain=n,t()},d.write("<bo"+"dy onload='document._boomrl();'>");else if(O._boomrl=function(){t()},O.addEventListener)O.addEventListener("load",O._boomrl,!1);else if(O.attachEvent)O.attachEvent("onload",O._boomrl);d.close()}function a(e){window.BOOMR_onload=e&&e.timeStamp||(new Date).getTime()}if(!window.BOOMR||!window.BOOMR.version&&!window.BOOMR.snippetExecuted){window.BOOMR=window.BOOMR||{},window.BOOMR.snippetStart=(new Date).getTime(),window.BOOMR.snippetExecuted=!0,window.BOOMR.snippetVersion=12,window.BOOMR.url=n+"FPXUV-CWEKR-ELG8D-URM4T-QZGQK";var i=document.currentScript||document.getElementsByTagName("script")[0],o=!1,r=document.createElement("link");if(r.relList&&"function"==typeof r.relList.supports&&r.relList.supports("preload")&&"as"in r)window.BOOMR.snippetMethod="p",r.href=window.BOOMR.url,r.rel="preload",r.as="script",r.addEventListener("load",e),r.addEventListener("error",function(){t(!0)}),setTimeout(function(){if(!o)t(!0)},3e3),BOOMR_lstart=(new Date).getTime(),i.parentNode.appendChild(r);else t(!1);if(window.addEventListener)window.addEventListener("load",a,!1);else if(window.attachEvent)window.attachEvent("onload",a)}}(),"".length>0)if(e&&"performance"in e&&e.performance&&"function"==typeof e.performance.setResourceTimingBufferSize)e.performance.setResourceTimingBufferSize();!function(){if(BOOMR=e.BOOMR||{},BOOMR.plugins=BOOMR.plugins||{},!BOOMR.plugins.AK){var n=""=="true"?1:0,t="",a="x326cxgj2qqcwzynwftq-f-0ef1aaae3-clientnsv4-s.akamaihd.net",i="false"=="true"?2:1,o={"ak.v":"39","ak.cp":"847416","ak.ai":parseInt("541075",10),"ak.ol":"0","ak.cr":21,"ak.ipv":4,"ak.proto":"http/1.1","ak.rid":"3ebba88d","ak.r":37959,"ak.a2":n,"ak.m":"dscr","ak.n":"ff","ak.bpcip":"190.245.225.0","ak.cport":60828,"ak.gh":"201.212.32.39","ak.quicv":"","ak.tlsv":"tls1.3","ak.0rtt":"","ak.0rtt.ed":"","ak.csrc":"-","ak.acc":"reno","ak.t":"1728950631","ak.ak":"hOBiQwZUYzCg5VSAfCLimQ==...","ak.pv":"180","ak.dpoabenc":"","ak.tf":i};if(""!==t)o["ak.ruds"]=t;var r={i:!1,av:function(n){var t="http.initiator";if(n&&(!n[t]||"spa_hard"===n[t]))o["ak.feo"]=void 0!==e.aFeoApplied?1:0,BOOMR.addVar(o)},rv:function(){var e=["ak.bpcip","ak.cport","ak.cr","ak.csrc","ak.gh","ak.ipv","ak.m","ak.n","ak.ol","ak.proto","ak.quicv","ak.tlsv","ak.0rtt","ak.0rtt.ed","ak.r","ak.acc","ak.t","ak.tf"];BOOMR.removeVar(e)}};BOOMR.plugins.AK={akVars:o,akDNSPreFetchDomain:a,init:function(){if(!r.i){var e=BOOMR.subscribe;e("before_beacon",r.av,null,null),e("onbeacon",r.rv,null,null),r.i=!0}return this},is_complete:function(){return!0}}}}()}(window);</script></head><body class="ln"><noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-GHV6" style="display:none;visibility:hidden ...
#         window.googlefc = window.googlefc || {};
#         googlefc.controlledMessagingFunction = function (message) {
#             message.proceed(true);
#         };
#     </script><script async="" env="prod" id="userClientLibs-home" src="https://static.glanacion.com/v2/registracionclientlibs/userClientLibs-3.5.9-7997b44.js"></script><script defer="" id="script-logo-event" src="/pf/resources/js/LN/scriptLogoEvent.min.js?d=1690" type="text/javascript"></script></body></html>

# %%
# Encontramos todos los elementos <a> (links) con el atributo href
links = soup.find_all('section')

print(type(links))
print(links)
# Out:
# <class 'bs4.element.ResultSet'>
# [<section class="pre-container mb-32" data-section="pre-apertura"><div data-fusion-component="c0f5KCrB2QxPanT" id="fusion-static-enter:c0f5KCrB2QxPanT" style="display:none"></div><div class="hidden" data-module="tema_00" id="c0f5KCrB2QxPanT"></div><div data-fusion-component="c0f5KCrB2QxPanT" id="fusion-static-exit:c0f5KCrB2QxPanT" style="display:none"></div><div data-fusion-component="f0fgNDqNS4g11oi" id="fusion-static-enter:f0fgNDqNS4g11oi" style="display:none"></div><div class="hidden" data-module="tema_enVivo" id="f0fgNDqNS4g11oi"><section data-block-name="h_enVivo" data-chain-id="f0fgNDqNS4g11oi" data-chain-position="04" data-diagramacion-id="enVivo" data-is-block="true"><div class="ln-live flex mb-16 border border-bottom border-thin border-neutral-light-100 --live" data-testid="live-component"><div class="flex lay-container"><div class="live-notes relative w-100 overflow-hidden"><div class="live-body py-16 pr-16 flex pt-0 --scroll-x --degrade-scroll mr-2"><span class="ln-badge inline-flex w-fit h-fit ai-center z-1 flex-nowrap text-12 rounded-16 bg-danger-600 text-light-0 uppercase py-6 pl-10 pr-8 gap-8 h-24 --live ai-center mr-8"><div class="pulse-animation"><div class="pulse w-5 h-5 bg-light-0 rounded-circle" style="animation-duration:1s;animation-timing-function:linear;animation-name:pulse-shadow;animation-iteration-count:infinite"></div></div>VIVO</span><ul class="live-list inline-flex --bullet-list_8 ai-center"><li class="flex ai-center"><article data-id="6YCLT2Z2HZHIRF5CXW4IZH6KGQ" data-notaid="6YCLT2Z2HZHIRF5CXW4IZH6KGQ" data-pos="9701" data-source="editor" group="1" id="6YCLT2Z2HZHIRF5CXW4IZH6KGQ"><a class="link ln-link notes flex ai-center gap-4 mt-4 w-max" href="/politica/javier-milei-en-vivo-las-ultimas-medidas-del-gobierno-nid14102024/" target="_self" title="Las medidas de Javier Milei"><h4 class="text ln-text text-neutral-light-800 --prumo --font-black --font-m">Las medidas de Javier Milei</h4><span class="text ln-text time-since mb-2 text-danger-600 --font-regular --font-xs">Hace 22 min</span></a></article></li></ul></div></div><div class="topics-container lg-only flex ai-center pl-16"><nav class="topics flex ai-center"><ul class="tag-list inline-flex text-light-800 --bullet-list_4"><li class="w-max flex ai-center"><a class="link text-neutral-light-800 --font-xs --unstyled" data-event="e_linkclick" data-section="MenuLN" href="https://www.lanacion.com.ar/tema/javier-milei-tid67207/" target="_self" title="Javier Milei">Javier Milei</a></li><li class="w-max flex ai-center"><a class="link text-neutral-light-800 --font-xs --unstyled" data-event="e_linkclick" data-section="MenuLN" href="https://www.lanacion.com.ar/dolar-hoy/" target="_self" title="Dólar hoy">Dólar hoy</a></li><li class="w-max flex ai-center"><a class="link text-neutral-light-800 --font-xs --unstyled" data-event="e_linkclick" data-section="MenuLN" href="https://www.lanacion.com.ar/tema/eliminatorias-tid46984/" target="_self" title="Eliminatorias">Eliminatorias</a></li></ul></nav></div></div></div></section></div><div data-fusion-component="f0fgNDqNS4g11oi" id="fusion-static-exit:f0fgNDqNS4g11oi" style="display:none"></div><div data-fusion-component="c0fE9QozblYZ52H" id="fusion-static-enter:c0fE9QozblYZ52H" style="display:none"></div><div class="hidden" data-module="tema_00" id="c0fE9QozblYZ52H"></div><div data-fusion-component="c0fE9QozblYZ52H" id="fusion-static-exit:c0fE9QozblYZ52H" style="display:none"></div></section>, <section data-block-name="h_enVivo" data-chain-id="f0fgNDqNS4g11oi" data-chain-position="04" data-diagramacion-id="enVivo" data-is-block="true"><div class="ln-live flex mb-16 border border-bottom border-thin border-neutral-light-100 --live" data-testid="live-component"><div class="flex lay-container"><div class="live-notes relative w-100 overflow-hidden"><div class="live-body py-16 pr-16 flex pt-0 --scroll-x --degrade-scroll mr-2"><span class="ln-badge inline-flex w-fit h-fit ai-center z-1 flex-nowrap text-12 rounded-16 bg-danger-6 ...

# %%
# Lista para almacenar los links de las noticias
news_links = []

# %%
# Extraer los valores de href de cada enlace
for link in links:
    href = link.get('href')

print(href)
# Out:
# None
